# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: - Killed
# Collecting package metadata: done
# Solving environment: \ Killed
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H' # your Foursquare ID
CLIENT_SECRET = '3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H
# CLIENT_SECRET:3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ

# %%
address = 'Perth, WA, Australia'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -31.9527121 115.8604796

# %% [markdown]
# # Italian

# %%
search_query = 'Italian'
radius = 200000
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H&client_secret=3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ&ll=-31.9527121,115.8604796&v=20180604&query=Italian&radius=200000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7ca404db04f505a1a40d70'},
#  'response': {'venues': [{'id': '514bec28e4b07ac94c9a34d7',
#     'name': "Jamie's Italian",
#     'location': {'address': '140 William St',
#      'crossStreet': 'Wellington St',
#      'lat': -31.951812426793865,
#      'lng': 115.85784149139874,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.951812426793865,
#        'lng': 115.85784149139874}],
#      'distance': 268,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['140 William St (Wellington St)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '5b7be6656dcf04002c6a0f6c',
#     'name': 'The Italian Corner',
#     'location': {'lat': -31.951391,
#      'lng': 115.85814,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.951391,
#        'lng': 115.85814}],
#      'distance': 265,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '594e6c8da4b51b7d05c41984',
#     'name': 'Simple Italian Cucina & Pizzeria',
#     'location': {'address': '413 Murray Street',
#      'lat': -31.951137021970908,
#      'lng': 115.8534455756295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.951137021970908,
#        'lng': 115.8534455756295}],
#      'distance': 687,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'neighborhood': 'Perth CBD',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['413 Murray Street', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '57429a01498eb87fd6f43cd7',
#     'name': "Jamie's Italian Perth",
#     'location': {'address': '140 William Street',
#      'lat': -31.951912,
#      'lng': 115.857936,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.951912,
#        'lng': 115.857936}],
#      'distance': 256,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['140 William Street', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '59df4cb1531593045dd97bc7',
#     'name': 'Simple Italian',
#     'location': {'lat': -31.952507,
#      'lng': 115.8528,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.952507,
#        'lng': 115.8528}],
#      'distance': 725,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4ba4aefbf964a52010ac38e3',
#     'name': 'The Italian Club',
#     'location': {'address': '219 Fitzgerald Street',
#      'crossStreet': 'btw Cowle & Lawley',
#      'lat': -31.939586993151472,
#      'lng': 115.85631142924619,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.939586993151472,
#        'lng': 115.85631142924619}],
#      'distance': 1513,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Northbridge',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['219 Fitzgerald Street (btw Cowle & Lawley)',
#       'Northbridge WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4c3d36a37c1ee21e3ab98d71',
#     'name': 'Italian Consulate Of Perth',
#     'location': {'address': '1292 Hay St',
#      'crossStreet': 'Outram st',
#      'lat': -31.94780962852802,
#      'lng': 115.83981756460513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94780962852802,
#        'lng': 115.83981756460513}],
#      'distance': 2026,
#      'cc': 'AU',
#      'city': 'West Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1292 Hay St (Outram st)',
#       'West Perth WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d12c951735',
#       'name': 'Embassy / Consulate',
#       'pluralName': 'Embassies / Consulates',
#       'shortName': 'Embassy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/embassy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4c5bb88f7f661b8dd0bd461c',
#     'name': 'Italian Club',
#     'location': {'address': '65 Marine Tce',
#      'lat': -32.05895648437925,
#      'lng': 115.74742743431848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05895648437925,
#        'lng': 115.74742743431848}],
#      'distance': 15930,
#      'postalCode': '6160',
#      'cc': 'AU',
#      'city': 'Fremantle',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['65 Marine Tce', 'Fremantle WA 6160', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4bc2bc61abf4952188ebc293',
#     'name': "Villa D'este",
#     'location': {'address': '49 Outram St',
#      'lat': -31.948495578740307,
#      'lng': 115.83966159513388,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.948495578740307,
#        'lng': 115.83966159513388}],
#      'distance': 2021,
#      'postalCode': '6005',
#      'cc': 'AU',
#      'city': 'West Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['49 Outram St', 'West Perth WA 6005', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4b456506f964a520ef0b26e3',
#     'name': "Sebastian's Italian Cafe",
#     'location': {'address': '851 Albany Hwy',
#      'crossStreet': 'Basinghall St',
#      'lat': -31.984746230509995,
#      'lng': 115.90300689161202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.984746230509995,
#        'lng': 115.90300689161202}],
#      'distance': 5370,
#      'postalCode': '6101',
#      'cc': 'AU',
#      'city': 'East Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['851 Albany Hwy (Basinghall St)',
#       'East Victoria Park WA 6101',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '520cc21e11d28c37867fc891',
#     'name': 'Gucce Italian Rest',
#     'location': {'address': 'Ardross St',
#      'lat': -32.0095,
#      'lng': 115.838,
#      'labeledLatLngs': [{'label': 'display', 'lat': -32.0095, 'lng': 115.838}],
#      'distance': 6668,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Ardross St', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4bbc7d6ee5b0d13acd466f7c',
#     'name': 'Italians',
#     'location': {'address': '165 Walter Rd West',
#      'lat': -31.899609679397795,
#      'lng': 115.8893035529609,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.899609679397795,
#        'lng': 115.8893035529609}],
#      'distance': 6508,
#      'postalCode': '6059',
#      'cc': 'AU',
#      'city': 'Dianella',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['165 Walter Rd West',
#       'Dianella WA 6059',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4cf775609d11b1f72a22c6ed',
#     'name': "Antonio's Italian",
#     'location': {'lat': -31.901371,
#      'lng': 115.799311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.901371,
#        'lng': 115.799311}],
#      'distance': 8127,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '51d3cd07498e0485b0e47c90',
#     'name': 'Mangia Italiano',
#     'location': {'address': 'Hay Street',
#      'lat': -31.947968553790126,
#      'lng': 115.84075337952818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.947968553790126,
#        'lng': 115.84075337952818}],
#      'distance': 1936,
#      'postalCode': '6005',
#      'cc': 'AU',
#      'city': 'West Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Hay Street', 'West Perth WA 6005', 'Australia']},
#     'categories': [],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4db5007281543d71da5060f3',
#     'name': 'Shahi Indian Cuisine',
#     'location': {'address': 'Canning Hwy.',
#      'crossStreet': 'Douglas Ave.',
#      'lat': -31.982229855912397,
#      'lng': 115.87615019654125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.982229855912397,
#        'lng': 115.87615019654125}],
#      'distance': 3603,
#      'cc': 'AU',
#      'city': 'South Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Canning Hwy. (Douglas Ave.)',
#       'South Perth WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4bd41eff462cb71305c1df07',
#     'name': 'Italian Club',
#     'location': {'lat': -32.05908062822706,
#      'lng': 115.74704604554668,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05908062822706,
#        'lng': 115.74704604554668}],
#      'distance': 15964,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4df9efd5aeb785aedbf0167a',
#     'name': 'Modo Mio Cucina Italiana',
#     'location': {'address': 'Bolton Ave',
#      'lat': -31.961622084145045,
#      'lng': 115.89442133903503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.961622084145045,
#        'lng': 115.89442133903503}],
#      'distance': 3355,
#      'postalCode': '6100',
#      'cc': 'AU',
#      'city': 'Burswood',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Bolton Ave', 'Burswood WA 6100', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4c56a8922308be9ab74a576c',
#     'name': "Leo's Pizza",
#     'location': {'address': 'Whatley Cres',
#      'crossStreet': 'Cnr Eighth Ave',
#      'lat': -31.928869981211722,
#      'lng': 115.8918579701737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.928869981211722,
#        'lng': 115.8918579701737}],
#      'distance': 3978,
#      'postalCode': '6051',
#      'cc': 'AU',
#      'city': 'Maylands',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Whatley Cres (Cnr Eighth Ave)',
#       'Maylands WA 6051',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4be95e88d837c9b62b51a606',
#     'name': 'Roman Palace Italian Restaurant',
#     'location': {'address': '25 Manning Road',
#      'crossStreet': 'Hamilton St',
#      'lat': -32.012825,
#      'lng': 115.924084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.012825,
#        'lng': 115.924084}],
#      'distance': 8991,
#      'postalCode': '6107',
#      'cc': 'AU',
#      'city': 'Cannington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['25 Manning Road (Hamilton St)',
#       'Cannington WA 6107',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4b59380af964a520c18128e3',
#     'name': 'Lambretta Cucina Italiana Restaurant',
#     'location': {'address': '45 Hampden Rd',
#      'lat': -31.97378753854041,
#      'lng': 115.81348890974607,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.97378753854041,
#        'lng': 115.81348890974607}],
#      'distance': 5019,
#      'postalCode': '6009',
#      'cc': 'AU',
#      'city': 'Nedlands',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['45 Hampden Rd', 'Nedlands WA 6009', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4d5e565614963704cf34c894',
#     'name': 'Italian Family Restaurant',
#     'location': {'lat': -31.809219,
#      'lng': 115.743731,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.809219,
#        'lng': 115.743731}],
#      'distance': 19414,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4fcb29a2e4b08a365329f86b',
#     'name': "claudio's Gourmet Italian Pizza",
#     'location': {'lat': -31.827518463134766,
#      'lng': 115.87443542480469,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.827518463134766,
#        'lng': 115.87443542480469}],
#      'distance': 13998,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4c3dab1d980320a11b448ce4',
#     'name': "Raffaele's Classic Italian Restaurant",
#     'location': {'lat': -32.070793,
#      'lng': 115.801952,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.070793,
#        'lng': 115.801952}],
#      'distance': 14258,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4d2303436e8c3704e9ae10a0',
#     'name': 'Campari Italian Restaurant',
#     'location': {'lat': -32.07467127577827,
#      'lng': 115.87928069406959,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.07467127577827,
#        'lng': 115.87928069406959}],
#      'distance': 13691,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '590efb8fcab4101c7a8812e7',
#     'name': "Tom's Italian",
#     'location': {'lat': -31.860428,
#      'lng': 115.753426,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.860428,
#        'lng': 115.753426}],
#      'distance': 14417,
#      'postalCode': '6020',
#      'cc': 'AU',
#      'city': 'North Beach',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['North Beach WA 6020', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4fb726fce4b00936587bbc8e',
#     'name': "Crena's Italian Cafe",
#     'location': {'lat': -32.053301,
#      'lng': 115.97791,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.053301,
#        'lng': 115.97791}],
#      'distance': 15756,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4b5d6a26f964a520515c29e3',
#     'name': 'Mambo Italiano',
#     'location': {'address': 'Shop 6 The Blvd',
#      'lat': -31.926709058707118,
#      'lng': 115.78645918328053,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.926709058707118,
#        'lng': 115.78645918328053}],
#      'distance': 7567,
#      'postalCode': '6015',
#      'cc': 'AU',
#      'city': 'City Beach',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 6 The Blvd',
#       'City Beach WA 6015',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '52b5ae9f498ef426eae45f7d',
#     'name': 'Ciao Italiano Restaurant',
#     'location': {'lat': -32.017599750404365,
#      'lng': 115.91052011088007,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.017599750404365,
#        'lng': 115.91052011088007}],
#      'distance': 8631,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4ddce257fa766a6d7945b705',
#     'name': 'Andiamo Italiano',
#     'location': {'lat': -31.877604,
#      'lng': 115.828876,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.877604,
#        'lng': 115.828876}],
#      'distance': 8878,
#      'cc': 'AU',
#      'city': 'Balcatta',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Balcatta WA', 'Australia']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4c63db4f58810f47789e0a1e',
#     'name': 'Swan Italian Club',
#     'location': {'address': 'Francis street',
#      'crossStreet': 'at Lloyd street',
#      'lat': -31.875244528400174,
#      'lng': 116.01627566342611,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.875244528400174,
#        'lng': 116.01627566342611}],
#      'distance': 17061,
#      'postalCode': '6056',
#      'cc': 'AU',
#      'city': 'Middle swan',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Francis street (at Lloyd street)',
#       'Middle Swan WA 6056',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4daacf661e72c1ab9bfc38cd',
#     'name': "Zacc's Italian Restaurant",
#     'location': {'lat': -32.06049479,
#      'lng': 116.00779247,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.06049479,
#        'lng': 116.00779247}],
#      'distance': 18366,
#      'postalCode': '6109',
#      'cc': 'AU',
#      'city': 'Maddington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Maddington WA 6109', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4d397e80bf6d548150bec3e1',
#     'name': 'Enrico Italian Restaurant',
#     'location': {'lat': -32.119681,
#      'lng': 115.818037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.119681,
#        'lng': 115.818037}],
#      'distance': 19013,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '56986ffa498e05b31b3017f8',
#     'name': 'Eight Slices Italian Kitchen',
#     'location': {'lat': -31.71801,
#      'lng': 115.78002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.71801,
#        'lng': 115.78002}],
#      'distance': 27212,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '5942677426659b27ebbafafe',
#     'name': 'La Vita Italian Restaurant & Wood Fired Pizza',
#     'location': {'address': '36 Central Walk',
#      'lat': -31.74335063440958,
#      'lng': 115.76954841613768,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.74335063440958,
#        'lng': 115.76954841613768}],
#      'distance': 24841,
#      'postalCode': '6027',
#      'cc': 'AU',
#      'city': 'Joondalup',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['36 Central Walk',
#       'Joondalup WA 6027',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4eaa7a975c5cf8848a420d56',
#     'name': 'Fremantle Italian Club',
#     'location': {'address': '65 marine tce',
#      'lat': -31.75234378532648,
#      'lng': 115.7417527769383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.75234378532648,
#        'lng': 115.7417527769383}],
#      'distance': 24970,
#      'cc': 'AU',
#      'city': 'Fremantle',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['65 marine tce', 'Fremantle WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d11a941735',
#       'name': 'Other Nightlife',
#       'pluralName': 'Other Nightlife',
#       'shortName': 'Nightlife',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '4f3f922de4b028ca58f9c414',
#     'name': 'The Italian Job',
#     'location': {'lat': -32.29258,
#      'lng': 115.719417,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.29258,
#        'lng': 115.719417}],
#      'distance': 40103,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '5870df09d60c8b34541832e3',
#     'name': 'Something Italian',
#     'location': {'lat': -31.659925,
#      'lng': 115.705966,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.659925,
#        'lng': 115.705966}],
#      'distance': 35720,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '5a85659360255e3c71526a39',
#     'name': 'Fusion Indo Italian',
#     'location': {'lat': -32.520546,
#      'lng': 115.75361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.520546,
#        'lng': 115.75361}],
#      'distance': 64006,
#      'postalCode': '6210',
#      'cc': 'AU',
#      'city': 'Greenfields',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Greenfields WA 6210', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '5af402157e4b4e0024ce5c31',
#     'name': 'Fusions Indo Italian Restaurant & Bar',
#     'location': {'address': '3/1 Eaglemont stree',
#      'crossStreet': '3/1 Eaglemont stree',
#      'lat': -32.523513075941885,
#      'lng': 115.76253175735474,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.523513075941885,
#        'lng': 115.76253175735474}],
#      'distance': 64206,
#      'postalCode': '6210',
#      'cc': 'AU',
#      'city': 'Greenfields',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['3/1 Eaglemont stree (3/1 Eaglemont stree)',
#       'Greenfields WA 6210',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False},
#    {'id': '5ad1b9fac824ae6eb0f5aaca',
#     'name': 'Italian Restaurant & Pizza Bar',
#     'location': {'lat': -31.551004,
#      'lng': 116.466161,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.551004,
#        'lng': 116.466161}],
#      'distance': 72709,
#      'postalCode': '6566',
#      'cc': 'AU',
#      'city': 'Toodyay',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Toodyay WA 6566', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672324',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
#
#                          id    location.address location.cc location.city  \
# 0  514bec28e4b07ac94c9a34d7      140 William St          AU         Perth
# 1  5b7be6656dcf04002c6a0f6c                 NaN          AU         Perth
# 2  594e6c8da4b51b7d05c41984   413 Murray Street          AU         Perth
# 3  57429a01498eb87fd6f43cd7  140 William Street          AU         Perth
# 4  59df4cb1531593045dd97bc7                 NaN          AU         Perth
#
#   location.country location.crossStreet  location.distance  \
# 0        Australia        Wellington St                268
# 1        Australia                  NaN                265
# 2        Australia                  NaN                687
# 3        Australia                  NaN                256
# 4        Australia                  NaN                725
#
#                            location.formattedAddress  \
# 0  [140 William St (Wellington St), Perth WA 6000...
# 1                         [Perth WA 6000, Australia]
# 2      [413 Murray Street, Perth WA 6000, Australia]
# 3     [140 William Street, Perth WA 6000, Australia]
# 4                         [Perth WA 6000, Australia]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -31.9518124267938...    -31.951812
# 1  [{'label': 'display', 'lat': -31.951391, 'lng'...    -31.951391
# 2  [{'label': 'display', 'lat': -31.9511370219709...    -31.951137
# 3  [{'label': 'display', 'lat': -31.951912, 'lng'...    -31.951912
# 4  [{'label': 'display', 'lat': -31.952507, 'lng'...    -31.952507
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    115.857841                   NaN                6000             WA
# 1    115.858140                   NaN                6000             WA
# 2    115.853446             Perth CBD                6000             WA
# 3    115.857936                   NaN                6000             WA
# 4    115.852800                   NaN                6000             WA
#
#                                name    referralId
# 0                   Jamie's Italian  v-1551672324
# 1                The Italian Corner  v-1551672324
# 2  Simple Italian Cucina & Pizzeria  v-1551672324
# 3             Jamie's Italian Perth  v-1551672324
# 4                    Simple Italian  v-1551672324

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
dataframe_filtered.to_csv('italian.csv')

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Perth

# add a red circle marker to represent the Paris
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Perth',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Mexican restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Vietnamise

# %%
search_query = 'Vietnamese'
radius = 200000
print(search_query + ' .... OK!')
# Out:
# Vietnamese .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H&client_secret=3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ&ll=-31.9527121,115.8604796&v=20180604&query=Vietnamese&radius=200000&limit=100'

# %%
results1 = requests.get(url).json()
results1
# Out:
# {'meta': {'code': 200, 'requestId': '5c7ca4584434b95786a376b5'},
#  'response': {'venues': [{'id': '4b5271e7f964a520a37d27e3',
#     'name': 'Tra Vinh Vietnamese',
#     'location': {'address': '297 William St.',
#      'crossStreet': 'Aberdeen St.',
#      'lat': -31.942862,
#      'lng': 115.86262,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.942862,
#        'lng': 115.86262}],
#      'distance': 1114,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'neighborhood': 'Perth CBD',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['297 William St. (Aberdeen St.)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '53115b0a11d2fce3c8bd9f4a',
#     'name': 'Okay Vietnamese Restaurant',
#     'location': {'address': 'Unit 6, 457-459 William St',
#      'lat': -31.942935943603516,
#      'lng': 115.86311340332031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.942935943603516,
#        'lng': 115.86311340332031}],
#      'distance': 1116,
#      'postalCode': '6003',
#      'cc': 'AU',
#      'city': 'Northbridge',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Unit 6, 457-459 William St',
#       'Northbridge WA 6003',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4e549448e4cd76151a3f66d9',
#     'name': 'Nonla Vietnamese Restaurant',
#     'location': {'lat': -31.953697,
#      'lng': 115.861076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953697,
#        'lng': 115.861076}],
#      'distance': 123,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Perth WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '525cc0e5498e588d71900a5f',
#     'name': 'East Cafe and Vietnamese Bistro',
#     'location': {'address': '4/447 Hay St',
#      'lat': -31.95621055979776,
#      'lng': 115.86502102399369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95621055979776,
#        'lng': 115.86502102399369}],
#      'distance': 579,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['4/447 Hay St', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4b5fc870f964a52090cc29e3',
#     'name': 'Phi Yen Vietnamese',
#     'location': {'address': '100 St Georges Tce',
#      'crossStreet': 'at Howard St',
#      'lat': -31.954092261066425,
#      'lng': 115.85807537048339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.954092261066425,
#        'lng': 115.85807537048339}],
#      'distance': 274,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['100 St Georges Tce (at Howard St)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4d4985b8782f370471126e37',
#     'name': 'Vietnamese Buddhist Temple',
#     'location': {'address': '45 Money Street.',
#      'lat': -31.947300172694504,
#      'lng': 115.86376646533955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.947300172694504,
#        'lng': 115.86376646533955}],
#      'distance': 677,
#      'postalCode': '6003',
#      'cc': 'AU',
#      'city': 'Highgate',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['45 Money Street.',
#       'Highgate WA 6003',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d13a941735',
#       'name': 'Temple',
#       'pluralName': 'Temples',
#       'shortName': 'Temple',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_temple_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '5a6b0a0c2be4255bbf684a94',
#     'name': 'Saigon Vietnamese & Asian Food',
#     'location': {'address': '876 Hay Street',
#      'lat': -31.952483,
#      'lng': 115.853464,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.952483,
#        'lng': 115.853464}],
#      'distance': 663,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['876 Hay Street', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4b526925f964a520f97b27e3',
#     'name': 'Toto Vietnamese Restaurant',
#     'location': {'address': '873 Albany Hwy',
#      'lat': -31.985584584935605,
#      'lng': 115.90375275781197,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.985584584935605,
#        'lng': 115.90375275781197}],
#      'distance': 5485,
#      'postalCode': '6101',
#      'cc': 'AU',
#      'city': 'East Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['873 Albany Hwy',
#       'East Victoria Park WA 6101',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4b5ef048f964a520a99e29e3',
#     'name': 'Viet Hoa',
#     'location': {'address': '1/349 William St',
#      'lat': -31.945309646243782,
#      'lng': 115.8615989644036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.945309646243782,
#        'lng': 115.8615989644036}],
#      'distance': 830,
#      'cc': 'AU',
#      'city': 'Northbridge',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1/349 William St', 'Northbridge WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '547ff7a0498eaa2a3fa1d851',
#     'name': 'vietnamese and thai Cuisine Lemongrass',
#     'location': {'lat': -31.94740678495377,
#      'lng': 115.82161473822052,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94740678495377,
#        'lng': 115.82161473822052}],
#      'distance': 3718,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '55336fb5498edd66447f47d9',
#     'name': 'Junkboat Vietnamese',
#     'location': {'lat': -31.938833523142545,
#      'lng': 115.86943856293679,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.938833523142545,
#        'lng': 115.86943856293679}],
#      'distance': 1761,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4b851006f964a5207f4a31e3',
#     'name': "Anna's Vietnamese",
#     'location': {'address': 'Oxford Street',
#      'lat': -31.935674265563744,
#      'lng': 115.84117940528829,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.935674265563744,
#        'lng': 115.84117940528829}],
#      'distance': 2630,
#      'postalCode': '6007',
#      'cc': 'AU',
#      'city': 'Leederville',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Oxford Street',
#       'Leederville WA 6007',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4b5ba1cdf964a5206a0c29e3',
#     'name': 'Holy Vietnamese Martyrs Centre',
#     'location': {'address': '3 Victoria Rd',
#      'lat': -31.860853803241266,
#      'lng': 115.82776721188338,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.860853803241266,
#        'lng': 115.82776721188338}],
#      'distance': 10682,
#      'postalCode': '6061',
#      'cc': 'AU',
#      'city': 'Westminster',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['3 Victoria Rd',
#       'Westminster WA 6061',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4c1065036b7e2d7f71ab2735',
#     'name': "Joy's Garden Vietnamese Restaurant",
#     'location': {'lat': -32.05615953006387,
#      'lng': 115.90278134955186,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05615953006387,
#        'lng': 115.90278134955186}],
#      'distance': 12188,
#      'cc': 'AU',
#      'state': 'Western Australia',
#      'country': 'Australia',
#      'formattedAddress': ['Western Australia', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4d1c8d91c50e6ea88372d3b8',
#     'name': "Wu's Vietnamese",
#     'location': {'lat': -31.976417,
#      'lng': 115.872895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.976417,
#        'lng': 115.872895}],
#      'distance': 2887,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '563f3a12cd10e06a3e53f92f',
#     'name': 'Phoever Vietnamese Cuisine',
#     'location': {'address': '29 Station Street',
#      'lat': -31.94432548704096,
#      'lng': 115.8236944633584,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94432548704096,
#        'lng': 115.8236944633584}],
#      'distance': 3597,
#      'cc': 'AU',
#      'city': 'Subiaco',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['29 Station Street', 'Subiaco WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4e8f01f630f8fd4d526b173a',
#     'name': 'Vietnamese Fusion',
#     'location': {'address': '168 Scarborough Beach Road',
#      'lat': -31.894038098118504,
#      'lng': 115.77490914100882,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.894038098118504,
#        'lng': 115.77490914100882}],
#      'distance': 10393,
#      'postalCode': '6019',
#      'cc': 'AU',
#      'city': 'Scarborough',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['168 Scarborough Beach Road',
#       'Scarborough WA 6019',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4ca2be0bf832a1cdb4ed97e5',
#     'name': 'Vietnamese Roll',
#     'location': {'lat': -31.835422,
#      'lng': 115.830015,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.835422,
#        'lng': 115.830015}],
#      'distance': 13370,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '567e3051498e1d6a1a30988c',
#     'name': 'Little Grill Vietnamese Cafe',
#     'location': {'address': 'Shop 1 363 Albany Hwy',
#      'lat': -31.97396236174115,
#      'lng': 115.89704065930896,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.97396236174115,
#        'lng': 115.89704065930896}],
#      'distance': 4185,
#      'postalCode': '6100',
#      'cc': 'AU',
#      'city': 'Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 1 363 Albany Hwy',
#       'Victoria Park WA 6100',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '57b81cd6498edc3df661e40e',
#     'name': 'Pho Ever Vietnamese Restaurant',
#     'location': {'address': '1236 Albany Hwy',
#      'lat': -32.00977367228199,
#      'lng': 115.92561542987823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.00977367228199,
#        'lng': 115.92561542987823}],
#      'distance': 8841,
#      'postalCode': '6107',
#      'cc': 'AU',
#      'city': 'Cannington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1236 Albany Hwy',
#       'Cannington WA 6107',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4bf8b6c05ec320a18e4e89d3',
#     'name': 'Toto Vietnamese',
#     'location': {'lat': -31.962791,
#      'lng': 115.914799,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.962791,
#        'lng': 115.914799}],
#      'distance': 5251,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4daa6a3f93a04642f08014c9',
#     'name': 'Phu Pho Vietnamese Fine Cuisine',
#     'location': {'lat': -31.98363381859604,
#      'lng': 115.90270049562493,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.98363381859604,
#        'lng': 115.90270049562493}],
#      'distance': 5267,
#      'cc': 'AU',
#      'city': 'East Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['East Victoria Park WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '55b322e7498ef089572fa7ed',
#     'name': 'Pearl Vietnamese Restaurant',
#     'location': {'lat': -31.960867113683307,
#      'lng': 115.92655132968665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.960867113683307,
#        'lng': 115.92655132968665}],
#      'distance': 6306,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '591564dba22db716fde48343',
#     'name': 'Uncle Lam Vietnamese Noodle House',
#     'location': {'address': '243/253 Walter Road West',
#      'lat': -31.894676,
#      'lng': 115.895701,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.894676,
#        'lng': 115.895701}],
#      'distance': 7267,
#      'postalCode': '6062',
#      'cc': 'AU',
#      'city': 'Morley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['243/253 Walter Road West',
#       'Morley WA 6062',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4bac2b21f964a520c0e83ae3',
#     'name': 'Vietnamese Hot Food',
#     'location': {'address': 'Shop 132, Wanneroo Markets',
#      'lat': -31.790345265209787,
#      'lng': 115.82010269165039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.790345265209787,
#        'lng': 115.82010269165039}],
#      'distance': 18473,
#      'postalCode': '6057',
#      'cc': 'AU',
#      'city': 'Wangara',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 132, Wanneroo Markets',
#       'Wangara WA 6057',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '5b093fb22db4a9002ccb119f',
#     'name': 'Papa Sweet Tooth',
#     'location': {'address': '878 Albany Hwy',
#      'lat': -31.985628,
#      'lng': 115.90395,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.985628,
#        'lng': 115.90395}],
#      'distance': 5502,
#      'postalCode': '6101',
#      'cc': 'AU',
#      'city': 'East Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['878 Albany Hwy',
#       'East Victoria Park WA 6101',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '5c11e0b6cabcff002c2ebfdf',
#     'name': 'Phoever Vietnamese Cuisine',
#     'location': {'address': 'Bannister Rd',
#      'crossStreet': 'Nr. Ranford Rd',
#      'lat': -32.071823,
#      'lng': 115.895685,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.071823,
#        'lng': 115.895685}],
#      'distance': 13669,
#      'postalCode': '6155',
#      'cc': 'AU',
#      'city': 'Canning Vale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Bannister Rd (Nr. Ranford Rd)',
#       'Canning Vale WA 6155',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4de61573ae607cf3446ba636',
#     'name': 'Viet Nosh Vietnamese Restaurant',
#     'location': {'address': '43 Hampden Road',
#      'lat': -31.836531140726457,
#      'lng': 115.76244563964039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.836531140726457,
#        'lng': 115.76244563964039}],
#      'distance': 15909,
#      'cc': 'AU',
#      'city': 'Nedlands',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['43 Hampden Road', 'Nedlands WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '52eda78f498e3a811ca48a9c',
#     'name': 'Perth Vietnamese Evangelical Church',
#     'location': {'address': '1 Thyme Court',
#      'lat': -31.858997678802726,
#      'lng': 115.85891447350765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.858997678802726,
#        'lng': 115.85891447350765}],
#      'distance': 10433,
#      'postalCode': '6061',
#      'cc': 'AU',
#      'city': 'Mirrabooka',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1 Thyme Court', 'Mirrabooka WA 6061', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '5885552b727ba3235cf6ae72',
#     'name': 'BMT Vietnamese Meat Rolls',
#     'location': {'lat': -31.834736,
#      'lng': 115.830728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.834736,
#        'lng': 115.830728}],
#      'distance': 13430,
#      'cc': 'AU',
#      'state': 'Western Australia',
#      'country': 'Australia',
#      'formattedAddress': ['Western Australia', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4fe45fd9e4b08d3cafc0463b',
#     'name': 'iPho Vietnamese Cuisine',
#     'location': {'address': 'Shop 1, 25 Collie Street',
#      'lat': -32.05601099118825,
#      'lng': 115.74707821898959,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05601099118825,
#        'lng': 115.74707821898959}],
#      'distance': 15710,
#      'postalCode': '6160',
#      'cc': 'AU',
#      'city': 'Fremantle',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 1, 25 Collie Street',
#       'Fremantle WA 6160',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4d3bc79dfb4c548186d6ce14',
#     'name': 'Hu Tieu Vietnamese & Chinese Cuisine',
#     'location': {'address': 'Shop 1/73',
#      'crossStreet': 'Honeywell Bld',
#      'lat': -31.83475397542989,
#      'lng': 115.83093293694229,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.83475397542989,
#        'lng': 115.83093293694229}],
#      'distance': 13424,
#      'postalCode': '6061',
#      'cc': 'AU',
#      'city': 'Mirrabooka Village Shopping Ce',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 1/73 (Honeywell Bld)',
#       'Mirrabooka Village Shopping Ce WA 6061',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '57300d5a498eab8b007deb31',
#     'name': 'Banh Mi Thit Phuong Nga Vietnamese Takeaway',
#     'location': {'address': 'Shop 7, 2 The Crescent',
#      'lat': -31.889564760810277,
#      'lng': 116.00373744964598,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.889564760810277,
#        'lng': 116.00373744964598}],
#      'distance': 15252,
#      'postalCode': '6056',
#      'cc': 'AU',
#      'city': 'Midland',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 7, 2 The Crescent',
#       'Midland WA 6056',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '5c7511f6d176e90025d84aea',
#     'name': 'Thien Kim Vietnamese',
#     'location': {'address': '9/1 Simms Rd',
#      'lat': -32.075237,
#      'lng': 115.781364,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.075237,
#        'lng': 115.781364}],
#      'distance': 15549,
#      'postalCode': '6163',
#      'cc': 'AU',
#      'city': 'Hamilton Hill',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['9/1 Simms Rd',
#       'Hamilton Hill WA 6163',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '4e3e342152b1a04aff231fbd',
#     'name': 'Tra Vinh Vietnamese Restaurant',
#     'location': {'lat': -32.08373294309526,
#      'lng': 115.91212558668127,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.08373294309526,
#        'lng': 115.91212558668127}],
#      'distance': 15378,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '5c3dc269237dee002ca9d3f3',
#     'name': 'Papa Vietnamese Food',
#     'location': {'address': 'shop 6a, Phoenix shopping center, 254 rockingham rd',
#      'lat': -32.097294,
#      'lng': 115.78365,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.097294,
#        'lng': 115.78365}],
#      'distance': 17652,
#      'postalCode': '6163',
#      'cc': 'AU',
#      'city': 'Spearwood',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['shop 6a, Phoenix shopping center, 254 rockingham rd',
#       'Spearwood WA 6163',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '53550b70498ed44d147086c1',
#     'name': 'BT & Friends Vietnamese Restaurant',
#     'location': {'lat': -31.742332085995496,
#      'lng': 115.77137874015953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.742332085995496,
#        'lng': 115.77137874015953}],
#      'distance': 24888,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False},
#    {'id': '57133fc8498e1bdf382d9467',
#     'name': 'Huong Sen Vietnamese Restaurant',
#     'location': {'address': 'Unit 3 / 12 Hughie Edward Drive',
#      'lat': -31.658952287962286,
#      'lng': 115.70666207281894,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.658952287962286,
#        'lng': 115.70666207281894}],
#      'distance': 35792,
#      'postalCode': '6030',
#      'cc': 'AU',
#      'city': 'Merriwa',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Unit 3 / 12 Hughie Edward Drive',
#       'Merriwa WA 6030',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672408',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues1 = results1['response']['venues']

# tranform venues into a dataframe
dataframe1 = json_normalize(venues1)
dataframe1.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...    False
# 1  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...    False
# 2  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 3  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...    False
# 4  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...    False
#
#                          id            location.address location.cc  \
# 0  4b5271e7f964a520a37d27e3             297 William St.          AU
# 1  53115b0a11d2fce3c8bd9f4a  Unit 6, 457-459 William St          AU
# 2  4e549448e4cd76151a3f66d9                         NaN          AU
# 3  525cc0e5498e588d71900a5f                4/447 Hay St          AU
# 4  4b5fc870f964a52090cc29e3          100 St Georges Tce          AU
#
#   location.city location.country location.crossStreet  location.distance  \
# 0         Perth        Australia         Aberdeen St.               1114
# 1   Northbridge        Australia                  NaN               1116
# 2         Perth        Australia                  NaN                123
# 3         Perth        Australia                  NaN                579
# 4         Perth        Australia         at Howard St                274
#
#                            location.formattedAddress  \
# 0  [297 William St. (Aberdeen St.), Perth WA 6000...
# 1  [Unit 6, 457-459 William St, Northbridge WA 60...
# 2                              [Perth WA, Australia]
# 3           [4/447 Hay St, Perth WA 6000, Australia]
# 4  [100 St Georges Tce (at Howard St), Perth WA 6...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -31.942862, 'lng'...    -31.942862
# 1  [{'label': 'display', 'lat': -31.9429359436035...    -31.942936
# 2  [{'label': 'display', 'lat': -31.953697, 'lng'...    -31.953697
# 3  [{'label': 'display', 'lat': -31.9562105597977...    -31.956211
# 4  [{'label': 'display', 'lat': -31.9540922610664...    -31.954092
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    115.862620             Perth CBD                6000             WA
# 1    115.863113                   NaN                6003             WA
# 2    115.861076                   NaN                 NaN             WA
# 3    115.865021                   NaN                6000             WA
# 4    115.858075                   NaN                6000             WA
#
#                               name    referralId
# 0              Tra Vinh Vietnamese  v-1551672408
# 1       Okay Vietnamese Restaurant  v-1551672408
# 2      Nonla Vietnamese Restaurant  v-1551672408
# 3  East Cafe and Vietnamese Bistro  v-1551672408
# 4               Phi Yen Vietnamese  v-1551672408

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns1 = ['name', 'categories'] + [col for col in dataframe1.columns if col.startswith('location.')] + ['id']
dataframe_filtered1 = dataframe1.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
dataframe_filtered1['categories'] = dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered1.columns = [column.split('.')[-1] for column in dataframe_filtered1.columns]

dataframe_filtered1
dataframe_filtered1.to_csv('vietnam.csv')

# %%
venues_map1 = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Perth
#folium.features.CircleMarker([latitude, longitude]).add_to(venues_map1)

# %%
# add the Mexican restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered1.lat, dataframe_filtered1.lng, dataframe_filtered1.categories):
    folium.features.CircleMarker([lat, lng],
                                 radius=5,  color='red', popup=label, 
                                 fill = True, fill_color='blue', fill_opacity=0.6).add_to(venues_map1)
venues_map1
# display map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
