# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: - Killed
# Collecting package metadata: done
# Solving environment: | Killed
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H' # your Foursquare ID
CLIENT_SECRET = '3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H
# CLIENT_SECRET:3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ

# %%
address = 'Perth, WA, Australia'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -31.9527121 115.8604796

# %% [markdown]
# # Mcdonalds

# %%
search_query = 'Mcdonalds'
radius = 200000
print(search_query + ' .... OK!')
# Out:
# Mcdonalds .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H&client_secret=3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ&ll=-31.9527121,115.8604796&v=20180604&query=Mcdonalds&radius=200000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7ca6576a60714c7f65a159'},
#  'response': {'venues': [{'id': '4b21eb39f964a520684224e3',
#     'name': "McDonald's",
#     'location': {'address': '78 William St',
#      'lat': -31.953132721182957,
#      'lng': 115.8571758023165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953132721182957,
#        'lng': 115.8571758023165}],
#      'distance': 315,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['78 William St', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b3ed656f964a52084a225e3',
#     'name': "McDonald's",
#     'location': {'address': '608 Hay St',
#      'crossStreet': 'at Barrack St',
#      'lat': -31.954647107019582,
#      'lng': 115.86042165508044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.954647107019582,
#        'lng': 115.86042165508044}],
#      'distance': 215,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['608 Hay St (at Barrack St)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4e735c1fb993272e5216dbf5',
#     'name': "McDonald's",
#     'location': {'address': 'Parry St.',
#      'crossStreet': 'Beaufort St.',
#      'lat': -31.946653237942936,
#      'lng': 115.86459122349935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.946653237942936,
#        'lng': 115.86459122349935}],
#      'distance': 778,
#      'postalCode': '6003',
#      'cc': 'AU',
#      'neighborhood': 'Northbridge',
#      'city': 'Northbridge',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Parry St. (Beaufort St.)',
#       'Northbridge WA 6003',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b430b06f964a520d6db25e3',
#     'name': "McDonald's",
#     'location': {'address': 'Canning Hwy',
#      'crossStreet': 'at Berwick St',
#      'lat': -31.97426155111839,
#      'lng': 115.88297122340602,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.97426155111839,
#        'lng': 115.88297122340602}],
#      'distance': 3204,
#      'postalCode': '6100',
#      'cc': 'AU',
#      'city': 'South Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Canning Hwy (at Berwick St)',
#       'South Perth WA 6100',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b64edb0f964a5206ada2ae3',
#     'name': "McDonald's",
#     'location': {'address': 'Charles St.',
#      'crossStreet': 'at Scarborough Beach Rd.',
#      'lat': -31.926520712710634,
#      'lng': 115.85187569722959,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.926520712710634,
#        'lng': 115.85187569722959}],
#      'distance': 3026,
#      'postalCode': '6006',
#      'cc': 'AU',
#      'city': 'North Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Charles St. (at Scarborough Beach Rd.)',
#       'North Perth WA 6006',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '514d991ee4b020b3aa0fb70d',
#     'name': "McDonald's",
#     'location': {'lat': -31.96205522998167,
#      'lng': 115.89422236485144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.96205522998167,
#        'lng': 115.89422236485144}],
#      'distance': 3352,
#      'cc': 'AU',
#      'city': 'Burswood',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Burswood WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b4e93cff964a520edf126e3',
#     'name': "McDonald's",
#     'location': {'address': '622 Hay St.',
#      'crossStreet': 'Cnr Jersey St.',
#      'lat': -31.947296836862844,
#      'lng': 115.81221852329544,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.947296836862844,
#        'lng': 115.81221852329544}],
#      'distance': 4598,
#      'postalCode': '6014',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['622 Hay St. (Cnr Jersey St.)',
#       'Jolimont WA 6014',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b87fba4f964a520c7d631e3',
#     'name': "McDonald's",
#     'location': {'address': 'Guildford Rd',
#      'crossStreet': 'at Caledonian Rd',
#      'lat': -31.92913069458955,
#      'lng': 115.89708658080438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.92913069458955,
#        'lng': 115.89708658080438}],
#      'distance': 4341,
#      'postalCode': '6051',
#      'cc': 'AU',
#      'city': 'Maylands',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Guildford Rd (at Caledonian Rd)',
#       'Maylands WA 6051',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4d043147a26854813587b6bd',
#     'name': "McDonald's",
#     'location': {'address': '1035 Albany Hwy',
#      'crossStreet': 'Alday St.',
#      'lat': -31.993679888600877,
#      'lng': 115.91218052653515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.993679888600877,
#        'lng': 115.91218052653515}],
#      'distance': 6680,
#      'postalCode': '6101',
#      'cc': 'AU',
#      'city': 'East Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1035 Albany Hwy (Alday St.)',
#       'East Victoria Park WA 6101',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b8a89c2f964a5203a7132e3',
#     'name': "McDonald's",
#     'location': {'address': '211 Wanneroo Rd',
#      'crossStreet': 'at Morley Dr.',
#      'lat': -31.88954875528049,
#      'lng': 115.83746811727262,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.88954875528049,
#        'lng': 115.83746811727262}],
#      'distance': 7359,
#      'postalCode': '6020',
#      'cc': 'AU',
#      'city': 'Tuart Hill',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['211 Wanneroo Rd (at Morley Dr.)',
#       'Tuart Hill WA 6020',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4c653c64f67ec92840fa5627',
#     'name': "McDonald's",
#     'location': {'address': 'Leach Hwy',
#      'crossStreet': 'at North Lake Rd.',
#      'lat': -32.045267929342714,
#      'lng': 115.81922869714388,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.045267929342714,
#        'lng': 115.81922869714388}],
#      'distance': 11014,
#      'postalCode': '6156',
#      'cc': 'AU',
#      'city': 'Melville',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Leach Hwy (at North Lake Rd.)',
#       'Melville WA 6156',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '59fa628228122f191e654ccc',
#     'name': "McDonald's",
#     'location': {'lat': -32.01159946678236,
#      'lng': 115.88465909939302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01159946678236,
#        'lng': 115.88465909939302}],
#      'distance': 6941,
#      'postalCode': '6152',
#      'cc': 'AU',
#      'city': 'Karawara',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Karawara WA 6152', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b75f9c7f964a5209a332ee3',
#     'name': "McDonald's",
#     'location': {'address': '388 Scarborough Beach Rd.',
#      'crossStreet': 'at Liege St.',
#      'lat': -31.90262922364349,
#      'lng': 115.79861494943776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.90262922364349,
#        'lng': 115.79861494943776}],
#      'distance': 8077,
#      'postalCode': '6018',
#      'cc': 'AU',
#      'city': 'Innaloo',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['388 Scarborough Beach Rd. (at Liege St.)',
#       'Innaloo WA 6018',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4c37399fc44a95217aab3d52',
#     'name': "McDonald's",
#     'location': {'address': 'Mirrabooka Ave.',
#      'crossStreet': 'at Yirrigan Drv.',
#      'lat': -31.87055907750273,
#      'lng': 115.85717171743272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.87055907750273,
#        'lng': 115.85717171743272}],
#      'distance': 9150,
#      'postalCode': '6061',
#      'cc': 'AU',
#      'city': 'Mirrabooka',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Mirrabooka Ave. (at Yirrigan Drv.)',
#       'Mirrabooka WA 6061',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b133195f964a520579523e3',
#     'name': "McDonald's",
#     'location': {'address': '1342 Albany Hwy',
#      'crossStreet': 'at Cecil Ave',
#      'lat': -32.01809558938474,
#      'lng': 115.93533250478593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01809558938474,
#        'lng': 115.93533250478593}],
#      'distance': 10145,
#      'cc': 'AU',
#      'city': 'Cannington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1342 Albany Hwy (at Cecil Ave)',
#       'Cannington WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4baaf3c2f964a5204d8f3ae3',
#     'name': "McDonald's",
#     'location': {'address': '182 Wanneroo Rd',
#      'crossStreet': 'nr Hepburn Ave.',
#      'lat': -31.81743591600767,
#      'lng': 115.82124854838449,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.81743591600767,
#        'lng': 115.82124854838449}],
#      'distance': 15508,
#      'postalCode': '6065',
#      'cc': 'AU',
#      'city': 'Madeley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['182 Wanneroo Rd (nr Hepburn Ave.)',
#       'Madeley WA 6065',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b2de3d8f964a520ebdb24e3',
#     'name': "McDonald's",
#     'location': {'address': 'Great Eastern Hwy',
#      'crossStreet': 'at Lyall St',
#      'lat': -31.934827367070636,
#      'lng': 115.93630539876963,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.934827367070636,
#        'lng': 115.93630539876963}],
#      'distance': 7434,
#      'postalCode': '6104',
#      'cc': 'AU',
#      'city': 'Ascot',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Great Eastern Hwy (at Lyall St)',
#       'Ascot WA 6104',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b249e35f964a520086924e3',
#     'name': "McDonald's",
#     'location': {'address': '285 Walter Rd',
#      'crossStreet': 'at Wheeler St',
#      'lat': -31.89450827656247,
#      'lng': 115.8998468797092,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.89450827656247,
#        'lng': 115.8998468797092}],
#      'distance': 7470,
#      'postalCode': '6062',
#      'cc': 'AU',
#      'city': 'Morley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['285 Walter Rd (at Wheeler St)',
#       'Morley WA 6062',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4bd32d7f046076b0fc5b7571',
#     'name': "McDonald's",
#     'location': {'address': 'Canning Hwy.',
#      'crossStreet': 'at Reynolds Rd',
#      'lat': -32.015353884355356,
#      'lng': 115.84266543388367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.015353884355356,
#        'lng': 115.84266543388367}],
#      'distance': 7173,
#      'postalCode': '6153',
#      'cc': 'AU',
#      'city': 'Applecross',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Canning Hwy. (at Reynolds Rd)',
#       'Applecross WA 6153',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b459717f964a5203e0e26e3',
#     'name': "McDonald's",
#     'location': {'address': 'Capital Rd',
#      'crossStreet': 'Bonner Dr',
#      'lat': -31.848786737316672,
#      'lng': 115.87842896320869,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.848786737316672,
#        'lng': 115.87842896320869}],
#      'distance': 11692,
#      'postalCode': '6090',
#      'cc': 'AU',
#      'city': 'Ballajura',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Capital Rd (Bonner Dr)',
#       'Ballajura WA 6090',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b85fb09f964a520687c31e3',
#     'name': "McDonald's",
#     'location': {'address': '328 Abernethy Rd.',
#      'crossStreet': 'at Belmont Forum Shopping Centre',
#      'lat': -31.963852422730472,
#      'lng': 115.93746941424035,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.963852422730472,
#        'lng': 115.93746941424035}],
#      'distance': 7376,
#      'postalCode': '6105',
#      'cc': 'AU',
#      'city': 'Cloverdale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['328 Abernethy Rd. (at Belmont Forum Shopping Centre)',
#       'Cloverdale WA 6105',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4bec05ea62c0c92863c8e2d4',
#     'name': "McDonald's",
#     'location': {'address': 'Canning Hwy.',
#      'crossStreet': 'at Foss St.',
#      'lat': -32.03583061308523,
#      'lng': 115.78565346962431,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.03583061308523,
#        'lng': 115.78565346962431}],
#      'distance': 11641,
#      'postalCode': '6157',
#      'cc': 'AU',
#      'city': 'Bicton',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Canning Hwy. (at Foss St.)',
#       'Bicton WA 6157',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b5e7b85f964a520659029e3',
#     'name': "McDonald's",
#     'location': {'address': '363 High Rd',
#      'lat': -32.03876070248108,
#      'lng': 115.90838951966857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.03876070248108,
#        'lng': 115.90838951966857}],
#      'distance': 10593,
#      'postalCode': '6148',
#      'cc': 'AU',
#      'city': 'Riverton',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['363 High Rd', 'Riverton WA 6148', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4bb973a0b35776b02bf6c901',
#     'name': "McDonald's",
#     'location': {'address': 'Beach Rd.',
#      'crossStreet': 'at Dorchester Rd..',
#      'lat': -31.844507111819286,
#      'lng': 115.80852365558958,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.844507111819286,
#        'lng': 115.80852365558958}],
#      'distance': 13007,
#      'cc': 'AU',
#      'city': 'Warwick',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Beach Rd. (at Dorchester Rd..)',
#       'Warwick WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4d9b4f55b4fa3704aa469a0d',
#     'name': "McDonald's",
#     'location': {'address': 'Burrandah Blvd',
#      'crossStreet': 'nr Pinetree Gully Rd',
#      'lat': -32.05724334432062,
#      'lng': 115.8813706602111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05724334432062,
#        'lng': 115.8813706602111}],
#      'distance': 11802,
#      'cc': 'AU',
#      'city': 'Willeton',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Burrandah Blvd (nr Pinetree Gully Rd)',
#       'Willeton WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b801e4ef964a520ce5330e3',
#     'name': "McDonald's",
#     'location': {'address': 'Nicholson Rd',
#      'crossStreet': 'at Ranford Rd',
#      'lat': -32.08795876173066,
#      'lng': 115.9172953833345,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.08795876173066,
#        'lng': 115.9172953833345}],
#      'distance': 15981,
#      'postalCode': '6155',
#      'cc': 'AU',
#      'city': 'Canning Vale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Nicholson Rd (at Ranford Rd)',
#       'Canning Vale WA 6155',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b78a5b7f964a520d6db2ee3',
#     'name': "McDonald's",
#     'location': {'address': '50/538 Kalamunda Rd.',
#      'lat': -31.93525906431625,
#      'lng': 116.00424471240294,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.93525906431625,
#        'lng': 116.00424471240294}],
#      'distance': 13718,
#      'postalCode': '6057',
#      'cc': 'AU',
#      'city': 'High Wycombe',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['50/538 Kalamunda Rd.',
#       'High Wycombe WA 6057',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4ba0d2faf964a520338037e3',
#     'name': "McDonald's",
#     'location': {'address': 'Marmion Ave',
#      'crossStreet': 'at Burragah Way',
#      'lat': -31.841342271640777,
#      'lng': 115.76355919767094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.841342271640777,
#        'lng': 115.76355919767094}],
#      'distance': 15414,
#      'postalCode': '6025',
#      'cc': 'AU',
#      'city': 'Duncraig',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Marmion Ave (at Burragah Way)',
#       'Duncraig WA 6025',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '567e131f498ec26fa2514a4e',
#     'name': "McDonald's",
#     'location': {'address': 'Cecil Ave & Albany Highway, Cannington WA 6107',
#      'lat': -32.01742,
#      'lng': 115.935126,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01742,
#        'lng': 115.935126}],
#      'distance': 10077,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Cecil Ave & Albany Highway, Cannington WA 6107',
#       'Perth WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4cd111cf5b5ca35d878c7ff0',
#     'name': "McDonald's",
#     'location': {'address': 'Centro Galleria, Collier Rd',
#      'crossStreet': 'nr Dewer St',
#      'lat': -31.897112713691598,
#      'lng': 115.89941652535785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.897112713691598,
#        'lng': 115.89941652535785}],
#      'distance': 7200,
#      'postalCode': '6063',
#      'cc': 'AU',
#      'city': 'Morley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Centro Galleria, Collier Rd (nr Dewer St)',
#       'Morley WA 6063',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4c3d95437d00d13ae0643a50',
#     'name': "McDonald's",
#     'location': {'address': '392 South St.',
#      'lat': -32.06508693098044,
#      'lng': 115.80119920244468,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.06508693098044,
#        'lng': 115.80119920244468}],
#      'distance': 13703,
#      'postalCode': '6163',
#      'cc': 'AU',
#      'city': "O'Connor",
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['392 South St.', "O'Connor WA 6163", 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4bc547320a30d13a75ea599c',
#     'name': "McDonald's",
#     'location': {'address': '231 Great Eastern Hwy',
#      'crossStreet': 'at Lloyd St',
#      'lat': -31.892188142751742,
#      'lng': 116.0131595044667,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.892188142751742,
#        'lng': 116.0131595044667}],
#      'distance': 15921,
#      'postalCode': '6056',
#      'cc': 'AU',
#      'city': 'Midland',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['231 Great Eastern Hwy (at Lloyd St)',
#       'Midland WA 6056',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b8ca24af964a520f3d832e3',
#     'name': "McDonald's",
#     'location': {'address': 'Albany Hwy.',
#      'crossStreet': 'at Olga Rd',
#      'lat': -32.05109998799689,
#      'lng': 115.98336935098658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05109998799689,
#        'lng': 115.98336935098658}],
#      'distance': 15954,
#      'postalCode': '6109',
#      'cc': 'AU',
#      'city': 'Maddington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Albany Hwy. (at Olga Rd)',
#       'Maddington WA 6109',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b782dcbf964a52036ba2ee3',
#     'name': "McDonald's",
#     'location': {'address': 'Gateways Shopping Centre Rd',
#      'crossStreet': 'nr Beeliar Dr',
#      'lat': -32.129826045224036,
#      'lng': 115.8541966152733,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.129826045224036,
#        'lng': 115.8541966152733}],
#      'distance': 19725,
#      'postalCode': '6164',
#      'cc': 'AU',
#      'city': 'Success',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Gateways Shopping Centre Rd (nr Beeliar Dr)',
#       'Success WA 6164',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b6d1ca8f964a52054672ce3',
#     'name': "McDonald's",
#     'location': {'address': '70 Hale Rd',
#      'crossStreet': 'at Hanover St',
#      'lat': -31.98900494477764,
#      'lng': 116.00936051631257,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.98900494477764,
#        'lng': 116.00936051631257}],
#      'distance': 14628,
#      'postalCode': '6058',
#      'cc': 'AU',
#      'city': 'Forrestfield',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['70 Hale Rd (at Hanover St)',
#       'Forrestfield WA 6058',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4be594cdbcef2d7feef603e5',
#     'name': "McDonald's",
#     'location': {'address': '159 Altone Rd',
#      'crossStreet': 'at Hull Way',
#      'lat': -31.870976469137823,
#      'lng': 115.94499839977924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.870976469137823,
#        'lng': 115.94499839977924}],
#      'distance': 12106,
#      'postalCode': '6063',
#      'cc': 'AU',
#      'city': 'Beechboro',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['159 Altone Rd (at Hull Way)',
#       'Beechboro WA 6063',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '50b7683be4b034401c0e9ada',
#     'name': "McDonald's",
#     'location': {'address': '95 Forest Lakes Dr',
#      'lat': -32.06981308154009,
#      'lng': 115.95246746340867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.06981308154009,
#        'lng': 115.95246746340867}],
#      'distance': 15662,
#      'postalCode': '6108',
#      'cc': 'AU',
#      'city': 'Forest Lakes',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['95 Forest Lakes Dr',
#       'Forest Lakes WA 6108',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b541b70f964a5206fb227e3',
#     'name': "McDonald's",
#     'location': {'address': '273 Eddystone Ave',
#      'crossStreet': 'at Ocean Reef Rd',
#      'lat': -31.770182472933023,
#      'lng': 115.7675373674141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.770182472933023,
#        'lng': 115.7675373674141}],
#      'distance': 22137,
#      'postalCode': '6027',
#      'cc': 'AU',
#      'city': 'Beldon',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['273 Eddystone Ave (at Ocean Reef Rd)',
#       'Beldon WA 6027',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4bb04375f964a520cd3e3ce3',
#     'name': "McDonald's",
#     'location': {'address': 'The Promenade',
#      'crossStreet': 'Pinaster Pde',
#      'lat': -31.781109163303423,
#      'lng': 115.96968981446643,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.781109163303423,
#        'lng': 115.96968981446643}],
#      'distance': 21714,
#      'postalCode': '6069',
#      'cc': 'AU',
#      'city': 'Ellenbrook',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['The Promenade (Pinaster Pde)',
#       'Ellenbrook WA 6069',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b481c00f964a5206c4826e3',
#     'name': "McDonald's",
#     'location': {'address': '420 Joondalup Dr',
#      'crossStreet': 'nr Cord St',
#      'lat': -31.742702472758804,
#      'lng': 115.764038363244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.742702472758804,
#        'lng': 115.764038363244}],
#      'distance': 25093,
#      'postalCode': '6027',
#      'cc': 'AU',
#      'city': 'Joondalup',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['420 Joondalup Dr (nr Cord St)',
#       'Joondalup WA 6027',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '5741cec2498ee283bea5ce8b',
#     'name': "McDonald's",
#     'location': {'address': 'Great Eastern Highway',
#      'crossStreet': 'Daly St',
#      'lat': -31.942392,
#      'lng': 115.925203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.942392,
#        'lng': 115.925203}],
#      'distance': 6220,
#      'cc': 'AU',
#      'city': 'Ascot',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Great Eastern Highway (Daly St)',
#       'Ascot WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b9c3f58f964a520b65836e3',
#     'name': "McDonald's",
#     'location': {'address': '254 Rockingham Rd',
#      'lat': -32.097550867061194,
#      'lng': 115.78305210955045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.097550867061194,
#        'lng': 115.78305210955045}],
#      'distance': 17701,
#      'postalCode': '6163',
#      'cc': 'AU',
#      'city': 'Spearwood',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['254 Rockingham Rd',
#       'Spearwood WA 6163',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4c98405bb6ee236a71dfa6a7',
#     'name': "McDonald's",
#     'location': {'address': 'Whitfords Ave',
#      'crossStreet': 'at Dampier Ave',
#      'lat': -31.796058322255217,
#      'lng': 115.7495325353576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.796058322255217,
#        'lng': 115.7495325353576}],
#      'distance': 20349,
#      'postalCode': '6025',
#      'cc': 'AU',
#      'city': 'Hillarys',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Whitfords Ave (at Dampier Ave)',
#       'Hillarys WA 6025',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4e476f21183849317e851f70',
#     'name': "McDonald's",
#     'location': {'lat': -32.06862951144458,
#      'lng': 115.81933279911082,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.06862951144458,
#        'lng': 115.81933279911082}],
#      'distance': 13475,
#      'cc': 'AU',
#      'state': 'Western Australia',
#      'country': 'Australia',
#      'formattedAddress': ['Western Australia', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b51b6a5f964a5204d5327e3',
#     'name': "McDonald's",
#     'location': {'address': '996 Wanneroo Rd',
#      'crossStreet': 'at Dundebar Rd',
#      'lat': -31.750830962771943,
#      'lng': 115.80233234005945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.750830962771943,
#        'lng': 115.80233234005945}],
#      'distance': 23135,
#      'postalCode': '6065',
#      'cc': 'AU',
#      'city': 'Wanneroo',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['996 Wanneroo Rd (at Dundebar Rd)',
#       'Wanneroo WA 6065',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4e8f4bec6da174e28dcd7fd5',
#     'name': "McDonald's",
#     'location': {'address': '79 Brisbane Street',
#      'lat': -31.99691919576537,
#      'lng': 115.86650433607097,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.99691919576537,
#        'lng': 115.86650433607097}],
#      'distance': 4953,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['79 Brisbane Street', 'Perth WA 6000', 'Australia']},
#     'categories': [],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4b4eb503f964a5205bf426e3',
#     'name': "McDonald's",
#     'location': {'address': '6 Delamere Ave',
#      'lat': -31.736878805727244,
#      'lng': 115.73732376752852,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.736878805727244,
#        'lng': 115.73732376752852}],
#      'distance': 26700,
#      'postalCode': '6028',
#      'cc': 'AU',
#      'city': 'Currambine',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['6 Delamere Ave',
#       'Currambine WA 6028',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4ba38138f964a520a54238e3',
#     'name': "McDonald's",
#     'location': {'address': '69 Jull St.',
#      'lat': -32.14987708642383,
#      'lng': 116.01919172317629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.14987708642383,
#        'lng': 116.01919172317629}],
#      'distance': 26569,
#      'postalCode': '6112',
#      'cc': 'AU',
#      'city': 'Armadale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['69 Jull St.', 'Armadale WA 6112', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '4bbcb36c4e069c7419c39de3',
#     'name': "McDonald's",
#     'location': {'address': '2901 Albany Hwy',
#      'lat': -32.117980619438484,
#      'lng': 116.01643997809143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.117980619438484,
#        'lng': 116.01643997809143}],
#      'distance': 23560,
#      'postalCode': '6111',
#      'cc': 'AU',
#      'city': 'Kelmscott',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2901 Albany Hwy',
#       'Kelmscott WA 6111',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False},
#    {'id': '534f2d4611d2e239174b800e',
#     'name': "McDonald's",
#     'location': {'address': '2158 Albany Hwy',
#      'lat': -32.06840302432061,
#      'lng': 115.99944172288971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.06840302432061,
#        'lng': 115.99944172288971}],
#      'distance': 18382,
#      'postalCode': '6053',
#      'cc': 'AU',
#      'city': 'Gosnells',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2158 Albany Hwy', 'Gosnells WA 6053', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672919',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 2  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 4  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
#
#                          id location.address location.cc location.city  \
# 0  4b21eb39f964a520684224e3    78 William St          AU         Perth
# 1  4b3ed656f964a52084a225e3       608 Hay St          AU         Perth
# 2  4e735c1fb993272e5216dbf5        Parry St.          AU   Northbridge
# 3  4b430b06f964a520d6db25e3      Canning Hwy          AU   South Perth
# 4  4b64edb0f964a5206ada2ae3      Charles St.          AU   North Perth
#
#   location.country      location.crossStreet  location.distance  \
# 0        Australia                       NaN                315
# 1        Australia             at Barrack St                215
# 2        Australia              Beaufort St.                778
# 3        Australia             at Berwick St               3204
# 4        Australia  at Scarborough Beach Rd.               3026
#
#                            location.formattedAddress  \
# 0          [78 William St, Perth WA 6000, Australia]
# 1  [608 Hay St (at Barrack St), Perth WA 6000, Au...
# 2  [Parry St. (Beaufort St.), Northbridge WA 6003...
# 3  [Canning Hwy (at Berwick St), South Perth WA 6...
# 4  [Charles St. (at Scarborough Beach Rd.), North...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -31.9531327211829...    -31.953133
# 1  [{'label': 'display', 'lat': -31.9546471070195...    -31.954647
# 2  [{'label': 'display', 'lat': -31.9466532379429...    -31.946653
# 3  [{'label': 'display', 'lat': -31.9742615511183...    -31.974262
# 4  [{'label': 'display', 'lat': -31.9265207127106...    -31.926521
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    115.857176                   NaN                6000             WA
# 1    115.860422                   NaN                6000             WA
# 2    115.864591           Northbridge                6003             WA
# 3    115.882971                   NaN                6100             WA
# 4    115.851876                   NaN                6006             WA
#
#          name    referralId
# 0  McDonald's  v-1551672919
# 1  McDonald's  v-1551672919
# 2  McDonald's  v-1551672919
# 3  McDonald's  v-1551672919
# 4  McDonald's  v-1551672919

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
dataframe_filtered.to_csv('Mcdonalds.csv')

# %%
dataframe_filtered.name
# Out:
# 0     McDonald's
# 1     McDonald's
# 2     McDonald's
# 3     McDonald's
# 4     McDonald's
# 5     McDonald's
# 6     McDonald's
# 7     McDonald's
# 8     McDonald's
# 9     McDonald's
# 10    McDonald's
# 11    McDonald's
# 12    McDonald's
# 13    McDonald's
# 14    McDonald's
# 15    McDonald's
# 16    McDonald's
# 17    McDonald's
# 18    McDonald's
# 19    McDonald's
# 20    McDonald's
# 21    McDonald's
# 22    McDonald's
# 23    McDonald's
# 24    McDonald's
# 25    McDonald's
# 26    McDonald's
# 27    McDonald's
# 28    McDonald's
# 29    McDonald's
# 30    McDonald's
# 31    McDonald's
# 32    McDonald's
# 33    McDonald's
# 34    McDonald's
# 35    McDonald's
# 36    McDonald's
# 37    McDonald's
# 38    McDonald's
# 39    McDonald's
# 40    McDonald's
# 41    McDonald's
# 42    McDonald's
# 43    McDonald's
# 44    McDonald's
# 45    McDonald's
# 46    McDonald's
# 47    McDonald's
# 48    McDonald's
# 49    McDonald's
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Perth

# add a red circle marker to represent the Paris
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Perth',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Mexican restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Hungry Jacks

# %%
search_query = 'Hungry Jacks'
radius = 200000
print(search_query + ' .... OK!')
# Out:
# Hungry Jacks .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H&client_secret=3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ&ll=-31.9527121,115.8604796&v=20180604&query=Hungry Jacks&radius=200000&limit=100'

# %%
results1 = requests.get(url).json()
results1
# Out:
# {'meta': {'code': 200, 'requestId': '5c7ca6b94434b95786ac88b4'},
#  'response': {'venues': [{'id': '4b58e1c3f964a520a97028e3',
#     'name': "Hungry Jack's",
#     'location': {'address': '92-94 William Street',
#      'lat': -31.952925484730613,
#      'lng': 115.85730887564073,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.952925484730613,
#        'lng': 115.85730887564073}],
#      'distance': 300,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['92-94 William Street',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4ce57a84023676eb42f8eab9',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Shop 25 Carillon Arcade Hay Street',
#      'lat': -31.953683529262502,
#      'lng': 115.8586330498929,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953683529262502,
#        'lng': 115.8586330498929}],
#      'distance': 205,
#      'cc': 'AU',
#      'city': 'Carillon',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 25 Carillon Arcade Hay Street',
#       'Carillon WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b2e20e1f964a520e3dc24e3',
#     'name': "Hungry Jack's",
#     'location': {'address': '581 Beaufort St',
#      'lat': -31.936331248336153,
#      'lng': 115.87078659808611,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.936331248336153,
#        'lng': 115.87078659808611}],
#      'distance': 2067,
#      'postalCode': '6050',
#      'cc': 'AU',
#      'neighborhood': 'Mt Lawley',
#      'city': 'Mt Lawley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['581 Beaufort St',
#       'Mt Lawley WA 6050',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b693febf964a520e19c2be3',
#     'name': "Hungry Jack's",
#     'location': {'address': '517 Hay St',
#      'crossStreet': 'Denis St',
#      'lat': -31.94724639031758,
#      'lng': 115.82240287710584,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94724639031758,
#        'lng': 115.82240287710584}],
#      'distance': 3647,
#      'postalCode': '6008',
#      'cc': 'AU',
#      'city': 'Subiaco',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['517 Hay St (Denis St)',
#       'Subiaco WA 6008',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b9b294ef964a52007f735e3',
#     'name': "Hungry Jack's",
#     'location': {'address': '208 Great Eastern Hwy',
#      'crossStreet': 'at Resolution Dr',
#      'lat': -31.940803453079095,
#      'lng': 115.92670944105755,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.940803453079095,
#        'lng': 115.92670944105755}],
#      'distance': 6394,
#      'postalCode': '6103',
#      'cc': 'AU',
#      'city': 'Belmont',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['208 Great Eastern Hwy (at Resolution Dr)',
#       'Belmont WA 6103',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bc328592a89ef3bd496f488',
#     'name': "Hungry Jack's",
#     'location': {'address': '2 Wiluna St',
#      'crossStreet': 'at Wanneroo Rd',
#      'lat': -31.911732496066172,
#      'lng': 115.84745883949384,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.911732496066172,
#        'lng': 115.84745883949384}],
#      'distance': 4724,
#      'postalCode': '6060',
#      'cc': 'AU',
#      'city': 'Dog Swamp',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2 Wiluna St (at Wanneroo Rd)',
#       'Dog Swamp WA 6060',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b8eb424f964a520123233e3',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Stirling Hwy',
#      'crossStreet': 'nr Bayview Tce',
#      'lat': -31.98313028360041,
#      'lng': 115.78037762124889,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.98313028360041,
#        'lng': 115.78037762124889}],
#      'distance': 8287,
#      'cc': 'AU',
#      'city': 'Claremont',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Stirling Hwy (nr Bayview Tce)',
#       'Claremont WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b66591bf964a520c21e2be3',
#     'name': "Hungry Jack's",
#     'location': {'address': '194 Walter Rd West',
#      'crossStreet': 'at Drake St',
#      'lat': -31.898151783829515,
#      'lng': 115.89160116771922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.898151783829515,
#        'lng': 115.89160116771922}],
#      'distance': 6747,
#      'postalCode': '6062',
#      'cc': 'AU',
#      'city': 'Morley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['194 Walter Rd West (at Drake St)',
#       'Morley WA 6062',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '5901e07cbb8d366fead1b4e3',
#     'name': 'Hungry Jacks',
#     'location': {'address': '9 Armadale Road',
#      'crossStreet': 'knock place',
#      'lat': -32.12688,
#      'lng': 115.862946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.12688,
#        'lng': 115.862946}],
#      'distance': 19389,
#      'postalCode': '6164',
#      'cc': 'AU',
#      'city': 'Jandakot',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['9 Armadale Road (knock place)',
#       'Jandakot WA 6164',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b9b6bd5f964a5204f0636e3',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Yirrigan Dr.',
#      'crossStreet': 'at Farrrier Rd.',
#      'lat': -31.872692708363193,
#      'lng': 115.86042863903009,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.872692708363193,
#        'lng': 115.86042863903009}],
#      'distance': 8907,
#      'postalCode': '6059',
#      'cc': 'AU',
#      'city': 'Mirrabooka',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Yirrigan Dr. (at Farrrier Rd.)',
#       'Mirrabooka WA 6059',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bc95ab6cc8cd13a799abbcf',
#     'name': "Hungry Jack's",
#     'location': {'address': '2/1 Marshall Rd',
#      'lat': -32.04551228363085,
#      'lng': 115.81792860259546,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.04551228363085,
#        'lng': 115.81792860259546}],
#      'distance': 11083,
#      'postalCode': '6154',
#      'cc': 'AU',
#      'city': 'Myaree',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2/1 Marshall Rd', 'Myaree WA 6154', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4ce50770e1dba35d95467f88',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Lot 100, 1377 - 1381 Albany Hwy',
#      'lat': -32.020903,
#      'lng': 115.936788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.020903,
#        'lng': 115.936788}],
#      'distance': 10465,
#      'postalCode': '6107',
#      'cc': 'AU',
#      'city': 'Cannington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Lot 100, 1377 - 1381 Albany Hwy',
#       'Cannington WA 6107',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b4fdc28f964a520d01727e3',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Canning Hwy',
#      'crossStreet': 'Berwick St',
#      'lat': -31.974886107234,
#      'lng': 115.88185795057855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.974886107234,
#        'lng': 115.88185795057855}],
#      'distance': 3188,
#      'cc': 'AU',
#      'city': 'South Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Canning Hwy (Berwick St)',
#       'South Perth WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b680b2cf964a52003652be3',
#     'name': "Hungry Jack's",
#     'location': {'address': '382 Scarborough Beach Rd',
#      'crossStreet': 'nr Liege St',
#      'lat': -31.901635320634924,
#      'lng': 115.797144066258,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.901635320634924,
#        'lng': 115.797144066258}],
#      'distance': 8254,
#      'postalCode': '6018',
#      'cc': 'AU',
#      'city': 'Innaloo',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['382 Scarborough Beach Rd (nr Liege St)',
#       'Innaloo WA 6018',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bc9b22fcc8cd13a2bf7bbcf',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Whitfords Ave',
#      'crossStreet': 'nr Endeavour Rd',
#      'lat': -31.79671712955049,
#      'lng': 115.74622339328769,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.79671712955049,
#        'lng': 115.74622339328769}],
#      'distance': 20450,
#      'postalCode': '6025',
#      'cc': 'AU',
#      'city': 'Hillarys',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Whitfords Ave (nr Endeavour Rd)',
#       'Hillarys WA 6025',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '567efe1a498e3cc40ef759bc',
#     'name': 'Hungry Jacks',
#     'location': {'address': 'Terminal 1 International, Airport Drive',
#      'lat': -31.94105,
#      'lng': 115.97465,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94105,
#        'lng': 115.97465}],
#      'distance': 10862,
#      'postalCode': '6105',
#      'cc': 'AU',
#      'city': 'Perth Airport',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Terminal 1 International, Airport Drive',
#       'Perth Airport WA 6105',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bdb9c6c2a3a0f475717b0b6',
#     'name': "Hungry Jack's",
#     'location': {'address': '100 Ranford Rd',
#      'crossStreet': 'Nicholson Rd',
#      'lat': -32.08746779959687,
#      'lng': 115.91730864496473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.08746779959687,
#        'lng': 115.91730864496473}],
#      'distance': 15930,
#      'postalCode': '6155',
#      'cc': 'AU',
#      'city': 'Canning Vale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['100 Ranford Rd (Nicholson Rd)',
#       'Canning Vale WA 6155',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b5a9641f964a520abcc28e3',
#     'name': "Hungry Jack's",
#     'location': {'address': '300 Benara Rd',
#      'crossStreet': 'nr Beechboro Rd Nth',
#      'lat': -31.87585210066883,
#      'lng': 115.9258300426634,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.87585210066883,
#        'lng': 115.9258300426634}],
#      'distance': 10551,
#      'postalCode': '6062',
#      'cc': 'AU',
#      'city': 'Noranda',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['300 Benara Rd (nr Beechboro Rd Nth)',
#       'Noranda WA 6062',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bdcfc783fae2d7fab0182e3',
#     'name': "Hungry Jack's",
#     'location': {'address': '200 Karrinyup Road',
#      'lat': -31.877396849285997,
#      'lng': 115.77664832329822,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.877396849285997,
#        'lng': 115.77664832329822}],
#      'distance': 11534,
#      'postalCode': '6018',
#      'cc': 'AU',
#      'city': 'Karrinyup',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['200 Karrinyup Road',
#       'Karrinyup WA 6018',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b63afc9f964a520198c2ae3',
#     'name': "Hungry Jack's",
#     'location': {'address': 'South St.',
#      'lat': -32.06546930012851,
#      'lng': 115.85824939229104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.06546930012851,
#        'lng': 115.85824939229104}],
#      'distance': 12553,
#      'cc': 'AU',
#      'city': 'Bull Creek',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['South St.', 'Bull Creek WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '5294a578498e53796d1dc4d3',
#     'name': 'Hungry Jacks',
#     'location': {'address': '21 Strelitzia Ave',
#      'lat': -31.986425069750073,
#      'lng': 116.01009872776744,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.986425069750073,
#        'lng': 116.01009872776744}],
#      'distance': 14619,
#      'postalCode': '6058',
#      'cc': 'AU',
#      'city': 'Forrestfield',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['21 Strelitzia Ave',
#       'Forrestfield WA 6058',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4ce57a86023676eba3f8eab9',
#     'name': "Hungry Jack's",
#     'location': {'address': '203 Warwick Rd',
#      'crossStreet': 'Glengarry Dr',
#      'lat': -31.835697579182774,
#      'lng': 115.7836890220642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.835697579182774,
#        'lng': 115.7836890220642}],
#      'distance': 14911,
#      'postalCode': '6023',
#      'cc': 'AU',
#      'city': 'Carine',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['203 Warwick Rd (Glengarry Dr)',
#       'Carine WA 6023',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '5bc8445161f070002c79ee9e',
#     'name': 'Hungry Jacks',
#     'location': {'address': 'Nicholson Rd',
#      'lat': -32.126453,
#      'lng': 115.925901,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.126453,
#        'lng': 115.925901}],
#      'distance': 20301,
#      'postalCode': '6112',
#      'cc': 'AU',
#      'city': 'Harrisdale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Nicholson Rd', 'Harrisdale WA 6112', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bc67196b387d13a32f9c1e8',
#     'name': "Hungry Jack's",
#     'location': {'address': 'North Lake Rd.',
#      'crossStreet': 'Cnr. Omeo St.',
#      'lat': -32.108026927286396,
#      'lng': 115.82852398530106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.108026927286396,
#        'lng': 115.82852398530106}],
#      'distance': 17550,
#      'postalCode': '6164',
#      'cc': 'AU',
#      'city': 'South Lake',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['North Lake Rd. (Cnr. Omeo St.)',
#       'South Lake WA 6164',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4c259c58905a0f4732ee6160',
#     'name': "Hungry Jack's",
#     'location': {'address': '2272 Albany Highway',
#      'crossStreet': 'at Bart St',
#      'lat': -32.07224929351294,
#      'lng': 116.00280493416285,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.07224929351294,
#        'lng': 116.00280493416285}],
#      'distance': 18908,
#      'postalCode': '6110',
#      'cc': 'AU',
#      'city': 'Gosnells',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2272 Albany Highway (at Bart St)',
#       'Gosnells WA 6110',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b67d88ef964a520225f2be3',
#     'name': "Hungry Jack's",
#     'location': {'address': '1545 Gnangara Rd',
#      'crossStreet': 'Henley Brook Ave',
#      'lat': -31.795061823988686,
#      'lng': 115.97952246665953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.795061823988686,
#        'lng': 115.97952246665953}],
#      'distance': 20847,
#      'postalCode': '6069',
#      'cc': 'AU',
#      'city': 'Aveley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1545 Gnangara Rd (Henley Brook Ave)',
#       'Aveley WA 6069',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4ce57a8c023676eb81f9eab9',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Spencer Village S/C',
#      'crossStreet': '210 Spencer Rd.',
#      'lat': -32.046227927672085,
#      'lng': 115.95263461886324,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.046227927672085,
#        'lng': 115.95263461886324}],
#      'distance': 13566,
#      'postalCode': '6108',
#      'cc': 'AU',
#      'city': 'Thornlie',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Spencer Village S/C (210 Spencer Rd.)',
#       'Thornlie WA 6108',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '58e474128ae36337c96cce8f',
#     'name': 'Hungry Jacks',
#     'location': {'address': 'Kalamunda Road',
#      'lat': -31.936271,
#      'lng': 116.006283,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.936271,
#        'lng': 116.006283}],
#      'distance': 13893,
#      'postalCode': '6057',
#      'cc': 'AU',
#      'city': 'High Wycombe',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Kalamunda Road',
#       'High Wycombe WA 6057',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4ce57a8b023676eb4bf9eab9',
#     'name': "Hungry Jack's",
#     'location': {'address': '2 Leghorn Street',
#      'lat': -32.28496370448065,
#      'lng': 115.73896215993577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.28496370448065,
#        'lng': 115.73896215993577}],
#      'distance': 38719,
#      'cc': 'AU',
#      'city': 'Rockingham',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2 Leghorn Street', 'Rockingham WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bf6ab47004ed13a33d942a0',
#     'name': "Hungry Jack's",
#     'location': {'address': '37 South Terrace',
#      'lat': -32.05620281299674,
#      'lng': 115.74838635890517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05620281299674,
#        'lng': 115.74838635890517}],
#      'distance': 15642,
#      'postalCode': '6160',
#      'cc': 'AU',
#      'city': 'Fremantle',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['37 South Terrace',
#       'Fremantle WA 6160',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4c28b3c7e19720a1004af858',
#     'name': 'Hungry Jacks',
#     'location': {'address': 'Warnbro Sound Ave',
#      'crossStreet': 'at Port Kennedy Drv',
#      'lat': -32.374258173095384,
#      'lng': 115.75613566684146,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.374258173095384,
#        'lng': 115.75613566684146}],
#      'distance': 47945,
#      'postalCode': '6172',
#      'cc': 'AU',
#      'city': 'Port Kennedy',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Warnbro Sound Ave (at Port Kennedy Drv)',
#       'Port Kennedy WA 6172',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4cfdf5cefeec6dcb551b5536',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Marmion Ave',
#      'crossStreet': 'nr Jindalee Blvd',
#      'lat': -31.648650490421897,
#      'lng': 115.69539070129395,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.648650490421897,
#        'lng': 115.69539070129395}],
#      'distance': 37277,
#      'cc': 'AU',
#      'city': 'Jindalee',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Marmion Ave (nr Jindalee Blvd)',
#       'Jindalee WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4b68f867f964a52055952be3',
#     'name': "Hungry Jack's",
#     'location': {'address': '420 Joondalup Dr',
#      'crossStreet': 'nr Dwyer Turn',
#      'lat': -31.741805591814288,
#      'lng': 115.76408139081978,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.741805591814288,
#        'lng': 115.76408139081978}],
#      'distance': 25185,
#      'postalCode': '6027',
#      'cc': 'AU',
#      'city': 'Joondalup',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['420 Joondalup Dr (nr Dwyer Turn)',
#       'Joondalup WA 6027',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4ce57a82023676ebfaf7eab9',
#     'name': "Hungry Jack's",
#     'location': {'address': '158 Jull St.',
#      'crossStreet': 'at Orchard Rd.',
#      'lat': -32.151446392133046,
#      'lng': 116.01637588927818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.151446392133046,
#        'lng': 116.01637588927818}],
#      'distance': 26566,
#      'postalCode': '6112',
#      'cc': 'AU',
#      'city': 'Armadale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['158 Jull St. (at Orchard Rd.)',
#       'Armadale WA 6112',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4ce57a8c023676eb67f9eab9',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Rockingham Rd.',
#      'crossStreet': 'Phoenix Rd.',
#      'lat': -32.09412935194753,
#      'lng': 115.78337520297093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.09412935194753,
#        'lng': 115.78337520297093}],
#      'distance': 17342,
#      'postalCode': '6163',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Rockingham Rd. (Phoenix Rd.)',
#       'Perth WA 6163',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4c0f66892466a59353877a21',
#     'name': 'Hungry Jacks',
#     'location': {'lat': -31.752254,
#      'lng': 115.802922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.752254,
#        'lng': 115.802922}],
#      'distance': 22968,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4cc2b1ef91413704732cb655',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Safety Bay Rd',
#      'crossStreet': 'at Baldivis Rd',
#      'lat': -32.33106233589492,
#      'lng': 115.82066222573123,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.33106233589492,
#        'lng': 115.82066222573123}],
#      'distance': 42284,
#      'postalCode': '6171',
#      'cc': 'AU',
#      'city': 'Baldivis',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Safety Bay Rd (at Baldivis Rd)',
#       'Baldivis WA 6171',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '52c7467b498e73da0a09ed93',
#     'name': 'Hungry Jacks',
#     'location': {'address': 'Marangaroo Drive',
#      'lat': -31.834483,
#      'lng': 115.829523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.834483,
#        'lng': 115.829523}],
#      'distance': 13482,
#      'cc': 'AU',
#      'city': 'Girrawheen',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Marangaroo Drive', 'Girrawheen WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4c88d2027223b1f788582ea8',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Great Eastern Hwy',
#      'crossStreet': 'at Mundaring Weir Rd',
#      'lat': -31.902317117838667,
#      'lng': 116.16793883163272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.902317117838667,
#        'lng': 116.16793883163272}],
#      'distance': 29584,
#      'cc': 'AU',
#      'city': 'Mundaring',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Great Eastern Hwy (at Mundaring Weir Rd)',
#       'Mundaring WA',
#       'Australia']},
#     'categories': [],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '53abc0b8498e80bd18547201',
#     'name': 'Hungry Jacks',
#     'location': {'address': 'Commerce Street',
#      'lat': -31.858241828621342,
#      'lng': 115.89416449201806,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.858241828621342,
#        'lng': 115.89416449201806}],
#      'distance': 10987,
#      'postalCode': '6090',
#      'cc': 'AU',
#      'city': 'Malaga',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Commerce Street', 'Malaga WA 6090', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bbab6c5cf2fc9b69ce8a102',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Unit 39 Stirling Central S/Ctr',
#      'lat': -31.863016165646876,
#      'lng': 115.82776721188338,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.863016165646876,
#        'lng': 115.82776721188338}],
#      'distance': 10452,
#      'cc': 'AU',
#      'city': 'Westminster',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Unit 39 Stirling Central S/Ctr',
#       'Westminster WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bd41e83a8b3a593f24a6b5f',
#     'name': "Hungry Jack's",
#     'location': {'address': '226-232 Great Eastern Hwy',
#      'lat': -31.89159438605836,
#      'lng': 116.01511838423498,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.89159438605836,
#        'lng': 116.01511838423498}],
#      'distance': 16117,
#      'postalCode': '6056',
#      'cc': 'AU',
#      'city': 'Midland',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['226-232 Great Eastern Hwy',
#       'Midland WA 6056',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '55519e9a498eb3b7e40056a3',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Manning Road',
#      'lat': -32.01194102474156,
#      'lng': 115.88431142532511,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01194102474156,
#        'lng': 115.88431142532511}],
#      'distance': 6966,
#      'cc': 'AU',
#      'city': 'KARAWARA',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Manning Road', 'Karawara WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4c85a5dcdc018cfa7c24ea6c',
#     'name': "Hungry Jack's",
#     'location': {'address': '32A Murray Rd',
#      'lat': -32.035447,
#      'lng': 115.789989,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.035447,
#        'lng': 115.789989}],
#      'distance': 11362,
#      'postalCode': '6157',
#      'cc': 'AU',
#      'city': 'Palmyra',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['32A Murray Rd', 'Palmyra WA 6157', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '5a9104d30f013c06c5e1720c',
#     'name': 'Hungry Jacks',
#     'location': {'address': '46 Gwendoline Drive',
#      'lat': -31.769327,
#      'lng': 115.765434,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.769327,
#        'lng': 115.765434}],
#      'distance': 22304,
#      'postalCode': '6027',
#      'cc': 'AU',
#      'city': 'Beldon',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['46 Gwendoline Drive',
#       'Beldon WA 6027',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '597c8eaec876c84ffb2cbb3c',
#     'name': "Hungry Jack's",
#     'location': {'address': 'Canning Hwy',
#      'lat': -32.01382,
#      'lng': 115.84641,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01382,
#        'lng': 115.84641}],
#      'distance': 6930,
#      'postalCode': '6153',
#      'cc': 'AU',
#      'city': 'Applecross',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Canning Hwy', 'Applecross WA 6153', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '567510cf498e5b59a6879c3d',
#     'name': 'Hungry Jacks',
#     'location': {'address': '1001 Joondalup Dr',
#      'crossStreet': 'Cnr Pinjar Rd',
#      'lat': -31.706451,
#      'lng': 115.801879,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.706451,
#        'lng': 115.801879}],
#      'distance': 27968,
#      'postalCode': '6031',
#      'cc': 'AU',
#      'city': 'Banksia Grove',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1001 Joondalup Dr (Cnr Pinjar Rd)',
#       'Banksia Grove WA 6031',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4ce57a89023676eb07f9eab9',
#     'name': "Hungry Jack's",
#     'location': {'address': '47 Yirrigan Drive',
#      'lat': -31.8694813661871,
#      'lng': 115.92215670147007,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.8694813661871,
#        'lng': 115.92215670147007}],
#      'distance': 10945,
#      'cc': 'AU',
#      'city': 'Mirrabooka',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['47 Yirrigan Drive', 'Mirrabooka WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '4bff2670ca1920a16e76ec81',
#     'name': "Hungry Jack's",
#     'location': {'address': '1874 Marmion Ave',
#      'lat': -31.690248802541745,
#      'lng': 115.71530207363048,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.690248802541745,
#        'lng': 115.71530207363048}],
#      'distance': 32283,
#      'cc': 'AU',
#      'city': 'Clarkson',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1874 Marmion Ave', 'Clarkson WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False},
#    {'id': '523d36d511d230e4a2b2560a',
#     'name': "Hungry Jack's Mirrabooka",
#     'location': {'lat': -31.872717,
#      'lng': 115.860349,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.872717,
#        'lng': 115.860349}],
#      'distance': 8904,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673017',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues1 = results1['response']['venues']

# tranform venues into a dataframe
dataframe1 = json_normalize(venues1)
dataframe1.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...    False
# 2  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 4  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
#
#                          id                    location.address location.cc  \
# 0  4b58e1c3f964a520a97028e3                92-94 William Street          AU
# 1  4ce57a84023676eb42f8eab9  Shop 25 Carillon Arcade Hay Street          AU
# 2  4b2e20e1f964a520e3dc24e3                     581 Beaufort St          AU
# 3  4b693febf964a520e19c2be3                          517 Hay St          AU
# 4  4b9b294ef964a52007f735e3               208 Great Eastern Hwy          AU
#
#   location.city location.country location.crossStreet  location.distance  \
# 0         Perth        Australia                  NaN                300
# 1      Carillon        Australia                  NaN                205
# 2     Mt Lawley        Australia                  NaN               2067
# 3       Subiaco        Australia             Denis St               3647
# 4       Belmont        Australia     at Resolution Dr               6394
#
#                            location.formattedAddress  \
# 0   [92-94 William Street, Perth WA 6000, Australia]
# 1  [Shop 25 Carillon Arcade Hay Street, Carillon ...
# 2    [581 Beaufort St, Mt Lawley WA 6050, Australia]
# 3  [517 Hay St (Denis St), Subiaco WA 6008, Austr...
# 4  [208 Great Eastern Hwy (at Resolution Dr), Bel...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -31.9529254847306...    -31.952925
# 1  [{'label': 'display', 'lat': -31.9536835292625...    -31.953684
# 2  [{'label': 'display', 'lat': -31.9363312483361...    -31.936331
# 3  [{'label': 'display', 'lat': -31.9472463903175...    -31.947246
# 4  [{'label': 'display', 'lat': -31.9408034530790...    -31.940803
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    115.857309                   NaN                6000             WA
# 1    115.858633                   NaN                 NaN             WA
# 2    115.870787             Mt Lawley                6050             WA
# 3    115.822403                   NaN                6008             WA
# 4    115.926709                   NaN                6103             WA
#
#             name    referralId
# 0  Hungry Jack's  v-1551673017
# 1  Hungry Jack's  v-1551673017
# 2  Hungry Jack's  v-1551673017
# 3  Hungry Jack's  v-1551673017
# 4  Hungry Jack's  v-1551673017

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns1 = ['name', 'categories'] + [col for col in dataframe1.columns if col.startswith('location.')] + ['id']
dataframe_filtered1 = dataframe1.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
dataframe_filtered1['categories'] = dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered1.columns = [column.split('.')[-1] for column in dataframe_filtered1.columns]

dataframe_filtered1
dataframe_filtered1.to_csv('Hungry Jacks')

# %%
venues_map1 = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Perth
#folium.features.CircleMarker([latitude, longitude]).add_to(venues_map1)

# %%
# add the Mexican restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered1.lat, dataframe_filtered1.lng, dataframe_filtered1.categories):
    folium.features.CircleMarker([lat, lng],
                                 radius=5,  color='red', popup=label, 
                                 fill = True, fill_color='blue', fill_opacity=0.6).add_to(venues_map1)
venues_map1
# display map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
