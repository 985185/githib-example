# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: - Killed
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H' # your Foursquare ID
CLIENT_SECRET = '3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H
# CLIENT_SECRET:3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ

# %%
address = 'Perth, WA, Australia'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -31.9527121 115.8604796

# %% [markdown]
# # Thai

# %%
search_query = 'Thai'
radius = 200000
print(search_query + ' .... OK!')
# Out:
# Thai .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H&client_secret=3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ&ll=-31.9527121,115.8604796&v=20180604&query=Thai&radius=200000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7ca56ff594df76b871652f'},
#  'response': {'venues': [{'id': '4b8b9f1bf964a520bfa432e3',
#     'name': 'S&T Thai Gourmet Cafe',
#     'location': {'address': 'Shop 3, 349 William St',
#      'lat': -31.94537453567843,
#      'lng': 115.86156374516699,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94537453567843,
#        'lng': 115.86156374516699}],
#      'distance': 823,
#      'postalCode': '6003',
#      'cc': 'AU',
#      'city': 'Northbridge',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 3, 349 William St',
#       'Northbridge WA 6003',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4dd365e07d8b6704c7a4ee33',
#     'name': 'Hi Thai',
#     'location': {'address': '100 St Georges Tce',
#      'lat': -31.954184992981187,
#      'lng': 115.85800864292321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.954184992981187,
#        'lng': 115.85800864292321}],
#      'distance': 285,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['100 St Georges Tce', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4b57ea70f964a520224628e3',
#     'name': "Tim's Thai",
#     'location': {'address': 'Shop 1, 1297 Hay Street',
#      'lat': -31.947969265696,
#      'lng': 115.83986762884945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.947969265696,
#        'lng': 115.83986762884945}],
#      'distance': 2017,
#      'postalCode': '6005',
#      'cc': 'AU',
#      'city': 'West Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 1, 1297 Hay Street',
#       'West Perth WA 6005',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4c58f51df346c9289b994bca',
#     'name': 'Ruby Thai',
#     'location': {'address': '146 Murray Street',
#      'lat': -31.95346617346296,
#      'lng': 115.86041628992825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95346617346296,
#        'lng': 115.86041628992825}],
#      'distance': 84,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['146 Murray Street', 'Perth WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4b9627fbf964a520a4be34e3',
#     'name': 'Yod Thai Cafe Lunch Bar',
#     'location': {'address': '328 Bulwer Street',
#      'lat': -31.938232,
#      'lng': 115.857508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.938232,
#        'lng': 115.857508}],
#      'distance': 1636,
#      'cc': 'AU',
#      'city': 'North Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['328 Bulwer Street', 'North Perth WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4e5dcbc714954da39fe77ebb',
#     'name': 'Hot Roast Thai',
#     'location': {'lat': -31.953238,
#      'lng': 115.859153,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953238,
#        'lng': 115.859153}],
#      'distance': 138,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Perth WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5bfa5cab4a1cc0002c51cd8d',
#     'name': 'Thai Thyme',
#     'location': {'lat': -31.951497,
#      'lng': 115.857559,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.951497,
#        'lng': 115.857559}],
#      'distance': 307,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5285817a11d2196af4e7175e',
#     'name': 'Hutt Tha Thai Massage',
#     'location': {'address': '2/117 Brisbane St',
#      'lat': -31.95424930006363,
#      'lng': 115.86106899981573,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95424930006363,
#        'lng': 115.86106899981573}],
#      'distance': 179,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2/117 Brisbane St', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4d7ef70695c1a14305e2dbf2',
#     'name': 'Thai Airways International',
#     'location': {'lat': -31.955456,
#      'lng': 115.859274,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.955456,
#        'lng': 115.859274}],
#      'distance': 325,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1f7931735',
#       'name': 'Plane',
#       'pluralName': 'Planes',
#       'shortName': 'Plane',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4e5b1e51d22dfba6f48a1edc',
#     'name': 'Bang Thai',
#     'location': {'address': 'Murray Street',
#      'lat': -31.953800238388602,
#      'lng': 115.85855634680627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953800238388602,
#        'lng': 115.85855634680627}],
#      'distance': 218,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Murray Street', 'Perth WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '59ad12859be5225c7b491b03',
#     'name': 'Busaba Thai Massage',
#     'location': {'address': 'Shop 213, Equus Arcade',
#      'crossStreet': '580 Hay Street',
#      'lat': -31.95471568175546,
#      'lng': 115.86090981960297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95471568175546,
#        'lng': 115.86090981960297}],
#      'distance': 226,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 213, Equus Arcade (580 Hay Street)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4e4dde441495fc2ca3e9d9d7',
#     'name': 'Thai Me',
#     'location': {'lat': -31.95333693949714,
#      'lng': 115.8552696454629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95333693949714,
#        'lng': 115.8552696454629}],
#      'distance': 496,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Perth WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '53e5f35d498e03a758be3635',
#     'name': 'Thai Orchid South Perth',
#     'location': {'address': 'Mends Str',
#      'lat': -31.971890668718977,
#      'lng': 115.84116929622367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.971890668718977,
#        'lng': 115.84116929622367}],
#      'distance': 2807,
#      'postalCode': '6151',
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Mends Str', '6151', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '53194509498efc58ccd8c90a',
#     'name': "That's Thai",
#     'location': {'lat': -31.953993910275244,
#      'lng': 115.85453605282575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953993910275244,
#        'lng': 115.85453605282575}],
#      'distance': 579,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5695de02498ef41197bc7e61',
#     'name': 'Ing Phu Aroma Thai Massage Therapy',
#     'location': {'address': '1/375 Hay St',
#      'lat': -31.956058373244627,
#      'lng': 115.86436986923218,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.956058373244627,
#        'lng': 115.86436986923218}],
#      'distance': 523,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'East Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1/375 Hay St', 'East Perth WA 6000', 'Australia']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4c2496e4136d20a13800e261',
#     'name': "That's a Little Thai Restaurant",
#     'location': {'address': '118 Aberdeen St. Northbridge',
#      'lat': -31.945676,
#      'lng': 115.85738,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.945676,
#        'lng': 115.85738}],
#      'distance': 836,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'state': 'Western Australia',
#      'country': 'Australia',
#      'formattedAddress': ['118 Aberdeen St. Northbridge',
#       'WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4d8c73a1376fa1cd5b274b70',
#     'name': 'Kai Pu Thai Entertainment',
#     'location': {'address': 'Unit 1 Forbes Road, Northbridge',
#      'lat': -31.94513913420018,
#      'lng': 115.86132026380847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94513913420018,
#        'lng': 115.86132026380847}],
#      'distance': 846,
#      'postalCode': '6003',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Unit 1 Forbes Road, Northbridge',
#       'Perth WA 6003',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5b0e78d30a08ab002cd49665',
#     'name': 'Happy Thai Restaurant',
#     'location': {'address': '835 Wellington Street',
#      'lat': -31.947955,
#      'lng': 115.847524,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.947955,
#        'lng': 115.847524}],
#      'distance': 1333,
#      'postalCode': '6005',
#      'cc': 'AU',
#      'city': 'West Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['835 Wellington Street',
#       'West Perth WA 6005',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '513c0405e4b04d69068b4964',
#     'name': 'Thai Food Festival',
#     'location': {'lat': -31.943129,
#      'lng': 115.867687,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.943129,
#        'lng': 115.867687}],
#      'distance': 1265,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4b94e757f964a520328734e3',
#     'name': 'Lanna Thai',
#     'location': {'address': '9/375 Hay St',
#      'lat': -31.947612052313335,
#      'lng': 115.82652455995935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.947612052313335,
#        'lng': 115.82652455995935}],
#      'distance': 3257,
#      'postalCode': '6008',
#      'cc': 'AU',
#      'city': 'Subiaco',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['9/375 Hay St', 'Subiaco WA 6008', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4f582cc1e4b0882cd67cf07d',
#     'name': 'Deva Aroma Thai Theraphy',
#     'location': {'lat': -31.942125599714426,
#      'lng': 115.86093037130055,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.942125599714426,
#        'lng': 115.86093037130055}],
#      'distance': 1179,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5932abce9ec39910e4438839',
#     'name': 'Khanom Thai',
#     'location': {'address': '219 Bulwer Street',
#      'lat': -31.940422,
#      'lng': 115.86182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.940422,
#        'lng': 115.86182}],
#      'distance': 1373,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['219 Bulwer Street', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4cfa2bbeee9cb60cdea088ad',
#     'name': 'Thai Delight Cuisine',
#     'location': {'address': 'Unit 2, 31 Pimlott st',
#      'lat': -31.886554,
#      'lng': 115.865881,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.886554,
#        'lng': 115.865881}],
#      'distance': 7382,
#      'cc': 'AU',
#      'city': 'Dianella',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Unit 2, 31 Pimlott st',
#       'Dianella WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4c1215c37f7f2d7f8399dc68',
#     'name': 'Wealthy Thai Cuisine',
#     'location': {'address': '259 Berwick St',
#      'lat': -31.986117,
#      'lng': 115.896781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.986117,
#        'lng': 115.896781}],
#      'distance': 5057,
#      'postalCode': '6101',
#      'cc': 'AU',
#      'city': 'East Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['259 Berwick St',
#       'East Victoria Park WA 6101',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4bf3b8fd354e9c7443a32602',
#     'name': 'nahm thai',
#     'location': {'address': '223 Bulwer Street',
#      'crossStreet': 'btw Bulwer & Lake',
#      'lat': -31.940261780820997,
#      'lng': 115.86179102216816,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.940261780820997,
#        'lng': 115.86179102216816}],
#      'distance': 1391,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['223 Bulwer Street (btw Bulwer & Lake)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4c0109b319d8c9282d2b8829',
#     'name': 'Thai Corner Restaurant',
#     'location': {'address': '3/795 Canning Hwy',
#      'lat': -32.014041418621915,
#      'lng': 115.84714959389626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.014041418621915,
#        'lng': 115.84714959389626}],
#      'distance': 6942,
#      'postalCode': '6153',
#      'cc': 'AU',
#      'city': 'Applecross',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['3/795 Canning Hwy',
#       'Applecross WA 6153',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4d4c012fa22c224b935bf593',
#     'name': 'Little Ying Thai',
#     'location': {'address': 'Albany Hwy',
#      'lat': -31.986664193833786,
#      'lng': 115.90443197430302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.986664193833786,
#        'lng': 115.90443197430302}],
#      'distance': 5613,
#      'postalCode': '6101',
#      'cc': 'AU',
#      'city': 'East Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Albany Hwy',
#       'East Victoria Park WA 6101',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '50814150e4b091f169640cda',
#     'name': 'Galangal Thai Cuisine',
#     'location': {'address': '64A',
#      'crossStreet': 'Etwell St.',
#      'lat': -31.994669,
#      'lng': 115.897402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.994669,
#        'lng': 115.897402}],
#      'distance': 5828,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['64A (Etwell St.)', 'Perth WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4f79eb13d4f2c803d0e3359d',
#     'name': 'Thai Airways Flight TG 482',
#     'location': {'address': 'Perth International Airport (PER)',
#      'lat': -31.9402999878,
#      'lng': 115.9670028687,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.9402999878,
#        'lng': 115.9670028687}],
#      'distance': 10156,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Perth International Airport (PER)',
#       'Perth WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1f7931735',
#       'name': 'Plane',
#       'pluralName': 'Planes',
#       'shortName': 'Plane',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5bef956d2db4a9002c704117',
#     'name': 'Sa-Lung Thai Cafe',
#     'location': {'address': '382 Fitzgerald Street',
#      'lat': -31.933538,
#      'lng': 115.859167,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.933538,
#        'lng': 115.859167}],
#      'distance': 2138,
#      'postalCode': '6006',
#      'cc': 'AU',
#      'city': 'North Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['382 Fitzgerald Street',
#       'North Perth WA 6006',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5040a59de4b0aa9bdb0c27d4',
#     'name': 'Siam Kitchen - Thai cuisine',
#     'location': {'lat': -31.947724,
#      'lng': 115.878011,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.947724,
#        'lng': 115.878011}],
#      'distance': 1746,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4c78d69681bca093686efb14',
#     'name': 'Million Thai Restaurant',
#     'location': {'address': '7/213 Kent St',
#      'lat': -32.01036559222714,
#      'lng': 115.88575447173379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01036559222714,
#        'lng': 115.88575447173379}],
#      'distance': 6847,
#      'postalCode': '6152',
#      'cc': 'AU',
#      'city': 'Karawara',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['7/213 Kent St', 'Karawara WA 6152', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4c628685edd320a1b809ad29',
#     'name': 'Thai Orchid',
#     'location': {'address': '35 Mends St',
#      'lat': -31.97195916494759,
#      'lng': 115.85286283792877,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.97195916494759,
#        'lng': 115.85286283792877}],
#      'distance': 2260,
#      'postalCode': '6151',
#      'cc': 'AU',
#      'city': 'South Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['35 Mends St', 'South Perth WA 6151', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4b94efa1f964a520608834e3',
#     'name': "JJ's Thai Cuisine",
#     'location': {'address': '5/240 Main St',
#      'lat': -31.895023,
#      'lng': 115.828378,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.895023,
#        'lng': 115.828378}],
#      'distance': 7102,
#      'postalCode': '6017',
#      'cc': 'AU',
#      'city': 'Osborne Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['5/240 Main St',
#       'Osborne Park WA 6017',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '52ca2248498ed783e3ffbaa4',
#     'name': 'Royal Thai Consulate Perth',
#     'location': {'lat': -31.949177944606166,
#      'lng': 115.83809611875174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.949177944606166,
#        'lng': 115.83809611875174}],
#      'distance': 2150,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d12c951735',
#       'name': 'Embassy / Consulate',
#       'pluralName': 'Embassies / Consulates',
#       'shortName': 'Embassy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/embassy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '58a97870158bbb1dcd2edf2a',
#     'name': 'Sama Sama Malaysian Thai Cuisine',
#     'location': {'address': '672 Beaufort Street',
#      'lat': -31.933962,
#      'lng': 115.872925,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.933962,
#        'lng': 115.872925}],
#      'distance': 2395,
#      'postalCode': '6050',
#      'cc': 'AU',
#      'city': 'Mt Lawley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['672 Beaufort Street',
#       'Mt Lawley WA 6050',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d156941735',
#       'name': 'Malay Restaurant',
#       'pluralName': 'Malay Restaurants',
#       'shortName': 'Malay',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4bfe54b88992a593bb52adb0',
#     'name': 'Thai Orchid Restaurant & Take Away',
#     'location': {'address': '776 Beaufort St',
#      'lat': -31.927540940746827,
#      'lng': 115.87925735022594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.927540940746827,
#        'lng': 115.87925735022594}],
#      'distance': 3316,
#      'postalCode': '6050',
#      'cc': 'AU',
#      'city': 'Mt Lawley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['776 Beaufort St',
#       'Mt Lawley WA 6050',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4bbd5dbef57ba5933814aeb9',
#     'name': 'Thai Café',
#     'location': {'lat': -31.977683,
#      'lng': 115.813957,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.977683,
#        'lng': 115.813957}],
#      'distance': 5199,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '557a635c498e3fc4d531b1e6',
#     'name': 'Pinto Thai Restaurant',
#     'location': {'address': '2 Moresby Street',
#      'lat': -31.988239204378047,
#      'lng': 115.87999689127427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.988239204378047,
#        'lng': 115.87999689127427}],
#      'distance': 4363,
#      'postalCode': '6151',
#      'cc': 'AU',
#      'city': 'Kensington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2 Moresby Street',
#       'Kensington WA 6151',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5780ab5dcd10361b6881301a',
#     'name': 'Rainbow Moon Thai Massage',
#     'location': {'address': '12 Washington St',
#      'crossStreet': 'Armagh St',
#      'lat': -31.971331813880436,
#      'lng': 115.8868145942688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.971331813880436,
#        'lng': 115.8868145942688}],
#      'distance': 3237,
#      'postalCode': '6100',
#      'cc': 'AU',
#      'city': 'Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['12 Washington St (Armagh St)',
#       'Victoria Park WA 6100',
#       'Australia']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4d3c25da05b8721e09c58937',
#     'name': 'Thai Esarn Restaurant',
#     'location': {'address': '1 Beechboro Rd',
#      'crossStreet': 'Drake St',
#      'lat': -31.916950337508293,
#      'lng': 115.91335726794684,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.916950337508293,
#        'lng': 115.91335726794684}],
#      'distance': 6387,
#      'postalCode': '6053',
#      'cc': 'AU',
#      'city': 'Bayswater',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1 Beechboro Rd (Drake St)',
#       'Bayswater WA 6053',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5798821d498e9da3d4f63d99',
#     'name': 'Thai Corner',
#     'location': {'lat': -32.019273,
#      'lng': 115.835985,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.019273,
#        'lng': 115.835985}],
#      'distance': 7762,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '547ff7a0498eaa2a3fa1d851',
#     'name': 'vietnamese and thai Cuisine Lemongrass',
#     'location': {'lat': -31.94740678495377,
#      'lng': 115.82161473822052,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94740678495377,
#        'lng': 115.82161473822052}],
#      'distance': 3718,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '51791b54e4b09dfb19047000',
#     'name': 'Sawadee Thai',
#     'location': {'lat': -31.954848,
#      'lng': 115.821334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.954848,
#        'lng': 115.821334}],
#      'distance': 3704,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4c77a342b4b4b60c2623280e',
#     'name': 'Royal Thai',
#     'location': {'address': 'Oxford St',
#      'crossStreet': 'Anzac Rd',
#      'lat': -31.925131,
#      'lng': 115.841404,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.925131,
#        'lng': 115.841404}],
#      'distance': 3560,
#      'cc': 'AU',
#      'city': 'Mt Hawthorn',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Oxford St (Anzac Rd)',
#       'Mt Hawthorn WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5104b61ae4b0f2b9587c60c6',
#     'name': 'Sabangna Thai',
#     'location': {'address': 'Station Street Markets',
#      'lat': -31.944398,
#      'lng': 115.822939,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.944398,
#        'lng': 115.822939}],
#      'distance': 3664,
#      'postalCode': '6008',
#      'cc': 'AU',
#      'city': 'Subiaco',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Station Street Markets',
#       'Subiaco WA 6008',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '55a69784498e608a39047157',
#     'name': 'Totally Thai Eating House',
#     'location': {'address': '46 Planet Street',
#      'crossStreet': 'Archer Street',
#      'lat': -31.976607060452118,
#      'lng': 115.91281859479916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.976607060452118,
#        'lng': 115.91281859479916}],
#      'distance': 5613,
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['46 Planet Street (Archer Street)',
#       'Perth WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '5885889c1ac004530de67709',
#     'name': 'THAI TATION',
#     'location': {'lat': -31.93679,
#      'lng': 115.792946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.93679,
#        'lng': 115.792946}],
#      'distance': 6620,
#      'postalCode': '6014',
#      'cc': 'AU',
#      'city': 'Floreat Forum',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Floreat Forum WA 6014', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4b74e988f964a520caf72de3',
#     'name': 'amarin thai',
#     'location': {'address': '180 rockeby rd',
#      'lat': -31.95009576279377,
#      'lng': 115.8242118358612,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95009576279377,
#        'lng': 115.8242118358612}],
#      'distance': 3437,
#      'cc': 'AU',
#      'city': 'Subiaco',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['180 rockeby rd', 'Subiaco WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False},
#    {'id': '4bcd9e4cfb84c9b62e3a223e',
#     'name': 'Krayaharn Thai Restaurant',
#     'location': {'address': 'Marmion Village',
#      'crossStreet': 'Sheppard Way',
#      'lat': -31.84425458842697,
#      'lng': 115.75467671943001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.84425458842697,
#        'lng': 115.75467671943001}],
#      'distance': 15676,
#      'postalCode': '6020',
#      'cc': 'AU',
#      'city': 'Marmion',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Marmion Village (Sheppard Way)',
#       'Marmion WA 6020',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672687',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 1  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 2  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 3  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 4  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
#
#                          id         location.address location.cc  \
# 0  4b8b9f1bf964a520bfa432e3   Shop 3, 349 William St          AU
# 1  4dd365e07d8b6704c7a4ee33       100 St Georges Tce          AU
# 2  4b57ea70f964a520224628e3  Shop 1, 1297 Hay Street          AU
# 3  4c58f51df346c9289b994bca        146 Murray Street          AU
# 4  4b9627fbf964a520a4be34e3        328 Bulwer Street          AU
#
#   location.city location.country location.crossStreet  location.distance  \
# 0   Northbridge        Australia                  NaN                823
# 1         Perth        Australia                  NaN                285
# 2    West Perth        Australia                  NaN               2017
# 3         Perth        Australia                  NaN                 84
# 4   North Perth        Australia                  NaN               1636
#
#                            location.formattedAddress  \
# 0  [Shop 3, 349 William St, Northbridge WA 6003, ...
# 1     [100 St Georges Tce, Perth WA 6000, Australia]
# 2  [Shop 1, 1297 Hay Street, West Perth WA 6005, ...
# 3           [146 Murray Street, Perth WA, Australia]
# 4     [328 Bulwer Street, North Perth WA, Australia]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -31.9453745356784...    -31.945375
# 1  [{'label': 'display', 'lat': -31.9541849929811...    -31.954185
# 2  [{'label': 'display', 'lat': -31.947969265696,...    -31.947969
# 3  [{'label': 'display', 'lat': -31.9534661734629...    -31.953466
# 4  [{'label': 'display', 'lat': -31.938232, 'lng'...    -31.938232
#
#    location.lng location.postalCode location.state                     name  \
# 0    115.861564                6003             WA    S&T Thai Gourmet Cafe
# 1    115.858009                6000             WA                  Hi Thai
# 2    115.839868                6005             WA               Tim's Thai
# 3    115.860416                 NaN             WA                Ruby Thai
# 4    115.857508                 NaN             WA  Yod Thai Cafe Lunch Bar
#
#      referralId
# 0  v-1551672687
# 1  v-1551672687
# 2  v-1551672687
# 3  v-1551672687
# 4  v-1551672687

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
dataframe_filtered.to_csv('thai.csv')

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Perth

# add a red circle marker to represent the Paris
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Perth',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Mexican restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Subway

# %%
search_query = 'Subway'
radius = 200000
print(search_query + ' .... OK!')
# Out:
# Subway .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H&client_secret=3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ&ll=-31.9527121,115.8604796&v=20180604&query=Subway&radius=200000&limit=100'

# %%
results1 = requests.get(url).json()
results1
# Out:
# {'meta': {'code': 200, 'requestId': '5c7ca5c6db04f505a45de61f'},
#  'response': {'venues': [{'id': '4ba45b50f964a5203e9838e3',
#     'name': 'Subway',
#     'location': {'address': '73 James St.',
#      'lat': -31.94888974620761,
#      'lng': 115.85886862184088,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94888974620761,
#        'lng': 115.85886862184088}],
#      'distance': 451,
#      'postalCode': '6003',
#      'cc': 'AU',
#      'city': 'Northbridge',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['73 James St.', 'Northbridge WA 6003', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4d6b10cb8fe6a143c81bf0a3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 109, Carillon City',
#      'crossStreet': '207 Murray St.',
#      'lat': -31.95380400986294,
#      'lng': 115.85855634680627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95380400986294,
#        'lng': 115.85855634680627}],
#      'distance': 218,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 109, Carillon City (207 Murray St.)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b416aecf964a52074c625e3',
#     'name': 'Subway',
#     'location': {'address': '564 Hay St.',
#      'lat': -31.955048676929177,
#      'lng': 115.86143610829562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.955048676929177,
#        'lng': 115.86143610829562}],
#      'distance': 275,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['564 Hay St.', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4bc3ebad920eb7137d341e2c',
#     'name': 'Subway',
#     'location': {'address': '256 Adelaide Tce',
#      'lat': -31.95791731365227,
#      'lng': 115.86582597611054,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95791731365227,
#        'lng': 115.86582597611054}],
#      'distance': 768,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['256 Adelaide Tce', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c86f818d8086dcba2d59e52',
#     'name': 'Subway',
#     'location': {'address': 'Shop 3, Allendale Square',
#      'crossStreet': '77 St Georges Tce',
#      'lat': -31.955706295122493,
#      'lng': 115.85801915585374,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.955706295122493,
#        'lng': 115.85801915585374}],
#      'distance': 406,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 3, Allendale Square (77 St Georges Tce)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b46b48ff964a5201c2726e3',
#     'name': 'Subway',
#     'location': {'address': '797 Hay St.',
#      'crossStreet': 'btwn William St. and King St.',
#      'lat': -31.953144327018617,
#      'lng': 115.85552140535002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953144327018617,
#        'lng': 115.85552140535002}],
#      'distance': 470,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['797 Hay St. (btwn William St. and King St.)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '50c017f3e4b0938053ef9bbb',
#     'name': 'Subway',
#     'location': {'address': 'Raine Square food court',
#      'crossStreet': 'Wellington Street',
#      'lat': -31.951379578123227,
#      'lng': 115.85262985782217,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.951379578123227,
#        'lng': 115.85262985782217}],
#      'distance': 756,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Raine Square food court (Wellington Street)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4cf8ddf0d76da35d9f4fc92c',
#     'name': 'Subway',
#     'location': {'address': 'Shop 19, Forrest Pl.',
#      'lat': -31.95217099892511,
#      'lng': 115.85948054375582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95217099892511,
#        'lng': 115.85948054375582}],
#      'distance': 111,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 19, Forrest Pl.',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b987246f964a520974235e3',
#     'name': 'Subway',
#     'location': {'address': '5/118 Royal St',
#      'crossStreet': 'at Plain St',
#      'lat': -31.95349394873558,
#      'lng': 115.87803312013652,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95349394873558,
#        'lng': 115.87803312013652}],
#      'distance': 1660,
#      'postalCode': '6004',
#      'cc': 'AU',
#      'city': 'East Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['5/118 Royal St (at Plain St)',
#       'East Perth WA 6004',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b67b4e4f964a520855b2be3',
#     'name': 'Subway',
#     'location': {'address': '3/1297 Hay St',
#      'crossStreet': 'at Outram St',
#      'lat': -31.94802485334464,
#      'lng': 115.8398755786099,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94802485334464,
#        'lng': 115.8398755786099}],
#      'distance': 2014,
#      'postalCode': '6005',
#      'cc': 'AU',
#      'city': 'West Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['3/1297 Hay St (at Outram St)',
#       'West Perth WA 6005',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b5d18eef964a5207e5229e3',
#     'name': 'Subway',
#     'location': {'address': '124 Oxford St.',
#      'crossStreet': 'at Newcastle St.',
#      'lat': -31.93755708783853,
#      'lng': 115.84135919809341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.93755708783853,
#        'lng': 115.84135919809341}],
#      'distance': 2471,
#      'postalCode': '6007',
#      'cc': 'AU',
#      'city': 'Leederville',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['124 Oxford St. (at Newcastle St.)',
#       'Leederville WA 6007',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b610becf964a520b7072ae3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 2, 683 Beaufort St',
#      'crossStreet': 'nr Walcott St',
#      'lat': -31.933294192708328,
#      'lng': 115.87308467491619,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.933294192708328,
#        'lng': 115.87308467491619}],
#      'distance': 2467,
#      'postalCode': '6050',
#      'cc': 'AU',
#      'city': 'Mt Lawley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 2, 683 Beaufort St (nr Walcott St)',
#       'Mt Lawley WA 6050',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b73db61f964a520e0bd2de3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 4, Subiaco Square',
#      'crossStreet': 'Subiaco Square Rd',
#      'lat': -31.944417138855645,
#      'lng': 115.82390862167003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.944417138855645,
#        'lng': 115.82390862167003}],
#      'distance': 3575,
#      'postalCode': '6008',
#      'cc': 'AU',
#      'city': 'Subiaco',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 4, Subiaco Square (Subiaco Square Rd)',
#       'Subiaco WA 6008',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '568b635d498efc5148cb326f',
#     'name': 'Subway',
#     'location': {'address': '137 Newcastle Street',
#      'crossStreet': 'Lindsay Street',
#      'lat': -31.949686950966736,
#      'lng': 115.86402639098367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.949686950966736,
#        'lng': 115.86402639098367}],
#      'distance': 475,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['137 Newcastle Street (Lindsay Street)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b862277f964a520d18031e3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 11, Eastgate S/C',
#      'crossStreet': '46 Great Eastern Hwy',
#      'lat': -31.95577812127443,
#      'lng': 115.90776270337993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95577812127443,
#        'lng': 115.90776270337993}],
#      'distance': 4478,
#      'postalCode': '6103',
#      'cc': 'AU',
#      'city': 'Rivervale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 11, Eastgate S/C (46 Great Eastern Hwy)',
#       'Rivervale WA 6103',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c4fbdc21886c9b6092c8927',
#     'name': 'Subway',
#     'location': {'address': 'cnr Abernathy & Kewdale Rd',
#      'lat': -31.97987025433926,
#      'lng': 115.95883436933578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.97987025433926,
#        'lng': 115.95883436933578}],
#      'distance': 9768,
#      'postalCode': '6105',
#      'cc': 'AU',
#      'city': 'Kewdale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['cnr Abernathy & Kewdale Rd',
#       'Kewdale WA 6105',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4dad09621e72c4e8dcb53fe1',
#     'name': 'Subway',
#     'location': {'address': 'Shop 104, Mirrabooka Square S/C',
#      'crossStreet': '43 Yirrigan Dr.',
#      'lat': -31.87160316477755,
#      'lng': 115.8612981217636,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.87160316477755,
#        'lng': 115.8612981217636}],
#      'distance': 9029,
#      'postalCode': '6061',
#      'cc': 'AU',
#      'city': 'Mirrabooka',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 104, Mirrabooka Square S/C (43 Yirrigan Dr.)',
#       'Mirrabooka WA 6061',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '50596332e4b0e7b3d58670fb',
#     'name': 'Subway',
#     'location': {'address': 'Milligan St',
#      'lat': -31.951470723518234,
#      'lng': 115.85167675522503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.951470723518234,
#        'lng': 115.85167675522503}],
#      'distance': 842,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Milligan St', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '510a5f83e4b0058902dd121e',
#     'name': 'Subway',
#     'location': {'address': 'Crown Casino Food Hall',
#      'lat': -31.961751079284333,
#      'lng': 115.89413561467805,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.961751079284333,
#        'lng': 115.89413561467805}],
#      'distance': 3334,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Crown Casino Food Hall', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b7b7abcf964a52003652fe3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 17, Glendalough S/C',
#      'crossStreet': '428 Jon Sanders Dr.',
#      'lat': -31.922479534685948,
#      'lng': 115.81918869647888,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.922479534685948,
#        'lng': 115.81918869647888}],
#      'distance': 5151,
#      'postalCode': '6016',
#      'cc': 'AU',
#      'city': 'Glendalough',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 17, Glendalough S/C (428 Jon Sanders Dr.)',
#       'Glendalough WA 6016',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4ba9f6d3f964a5203c403ae3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 2B, 236 Main St.',
#      'crossStreet': 'nr Eldorado St.',
#      'lat': -31.89529281149842,
#      'lng': 115.82851365692473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.89529281149842,
#        'lng': 115.82851365692473}],
#      'distance': 7069,
#      'postalCode': '6017',
#      'cc': 'AU',
#      'city': 'Osborne Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 2B, 236 Main St. (nr Eldorado St.)',
#       'Osborne Park WA 6017',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b9dd7c6f964a520ccbf36e3',
#     'name': 'Subway DC',
#     'location': {'address': '36 King St',
#      'lat': -31.952415,
#      'lng': 115.855005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.952415,
#        'lng': 115.855005}],
#      'distance': 518,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['36 King St', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '586495116431e50bfaf4a19c',
#     'name': 'Subway',
#     'location': {'address': '840 Wellington Street',
#      'crossStreet': 'Shop A01 Watertown',
#      'lat': -31.946846,
#      'lng': 115.84797,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.946846,
#        'lng': 115.84797}],
#      'distance': 1350,
#      'postalCode': '6005',
#      'cc': 'AU',
#      'city': 'West Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['840 Wellington Street (Shop A01 Watertown)',
#       'West Perth WA 6005',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4bdeb234ffdec9282c45e9a1',
#     'name': 'Subway',
#     'location': {'address': 'Shop 10, Maylands Park S/C',
#      'crossStreet': '228 Guilford Rd, nr Falkirk Ave.',
#      'lat': -31.929713896739294,
#      'lng': 115.89645860859362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.929713896739294,
#        'lng': 115.89645860859362}],
#      'distance': 4255,
#      'postalCode': '6051',
#      'cc': 'AU',
#      'city': 'Maylands',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 10, Maylands Park S/C (228 Guilford Rd, nr Falkirk Ave.)',
#       'Maylands WA 6051',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4bd7c5d835aad13a69ab8ff3',
#     'name': 'Subway',
#     'location': {'address': '501 Wanneroo Rd',
#      'lat': -31.86169630014727,
#      'lng': 115.82648108121919,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.86169630014727,
#        'lng': 115.82648108121919}],
#      'distance': 10628,
#      'postalCode': '6021',
#      'cc': 'AU',
#      'city': 'Balcatta',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['501 Wanneroo Rd', 'Balcatta WA 6021', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4bc3f6ce2a89ef3b69cff588',
#     'name': 'Subway',
#     'location': {'address': '639 Beach Rd',
#      'crossStreet': 'cnr Dorchester Ave.',
#      'lat': -31.84506770412081,
#      'lng': 115.80870367672973,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.84506770412081,
#        'lng': 115.80870367672973}],
#      'distance': 12943,
#      'postalCode': '6024',
#      'cc': 'AU',
#      'city': 'Warwick',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['639 Beach Rd (cnr Dorchester Ave.)',
#       'Warwick WA 6024',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b7e21bbf964a520e6e32fe3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 45, The Park S/C',
#      'crossStreet': '789 Albany Hwy',
#      'lat': -31.984009298224844,
#      'lng': 115.90128747298873,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.984009298224844,
#        'lng': 115.90128747298873}],
#      'distance': 5195,
#      'postalCode': '6101',
#      'cc': 'AU',
#      'city': 'East Victoria Park',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 45, The Park S/C (789 Albany Hwy)',
#       'East Victoria Park WA 6101',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b8b87bbf964a520fda132e3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 26, Dogswamp S/C',
#      'crossStreet': 'cnr Wanneroo & Wiluna Rd',
#      'lat': -31.91099,
#      'lng': 115.846895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.91099,
#        'lng': 115.846895}],
#      'distance': 4818,
#      'postalCode': '6060',
#      'cc': 'AU',
#      'city': 'Yokine',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 26, Dogswamp S/C (cnr Wanneroo & Wiluna Rd)',
#       'Yokine WA 6060',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c7b7bc176ce9c7434a7b70c',
#     'name': 'Subway',
#     'location': {'address': '200 Great Eastern Hwy',
#      'lat': -31.941349268247283,
#      'lng': 115.92615163819598,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.941349268247283,
#        'lng': 115.92615163819598}],
#      'distance': 6330,
#      'postalCode': '6104',
#      'cc': 'AU',
#      'city': 'Ascot',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['200 Great Eastern Hwy',
#       'Ascot WA 6104',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4ca2c4c6d5a2a1434aea4390',
#     'name': 'Subway',
#     'location': {'address': 'Shop 6, 108 Welshpool Rd',
#      'crossStreet': 'cnr Leach Hwy',
#      'lat': -31.993727167291865,
#      'lng': 115.92931742462765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.993727167291865,
#        'lng': 115.92931742462765}],
#      'distance': 7943,
#      'postalCode': '6106',
#      'cc': 'AU',
#      'city': 'Welshpool',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 6, 108 Welshpool Rd (cnr Leach Hwy)',
#       'Welshpool WA 6106',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4de31eadae60e7f3ac00b971',
#     'name': 'Subway',
#     'location': {'address': '301 Collier Rd',
#      'crossStreet': 'at Jackson St.',
#      'lat': -31.905781123060347,
#      'lng': 115.92715190392262,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.905781123060347,
#        'lng': 115.92715190392262}],
#      'distance': 8183,
#      'postalCode': '6054',
#      'cc': 'AU',
#      'city': 'Bassendean',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['301 Collier Rd (at Jackson St.)',
#       'Bassendean WA 6054',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c29b9e9e19720a1d4e6f958',
#     'name': 'Subway',
#     'location': {'address': 'Unit 10, Stirling Axis',
#      'crossStreet': '51 Cedric St. at Karrinyup Rd',
#      'lat': -31.886374483175153,
#      'lng': 115.8093510486418,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.886374483175153,
#        'lng': 115.8093510486418}],
#      'distance': 8824,
#      'postalCode': '6021',
#      'cc': 'AU',
#      'city': 'Stirling',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Unit 10, Stirling Axis (51 Cedric St. at Karrinyup Rd)',
#       'Stirling WA 6021',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c6f61ad34443704411f215f',
#     'name': 'Subway',
#     'location': {'address': 'Shop 63, Floreat Forum S/C',
#      'crossStreet': '1 Howtrees Pl.',
#      'lat': -31.937085915313673,
#      'lng': 115.79280853271484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.937085915313673,
#        'lng': 115.79280853271484}],
#      'distance': 6624,
#      'postalCode': '6014',
#      'cc': 'AU',
#      'city': 'Floreat',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 63, Floreat Forum S/C (1 Howtrees Pl.)',
#       'Floreat WA 6014',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b7cc790f964a52033a52fe3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 1, 15 Bonner Dr.',
#      'crossStreet': 'nr Capital Rd',
#      'lat': -31.8498481892533,
#      'lng': 115.87829397209116,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.8498481892533,
#        'lng': 115.87829397209116}],
#      'distance': 11573,
#      'postalCode': '6090',
#      'cc': 'AU',
#      'city': 'Malaga',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 1, 15 Bonner Dr. (nr Capital Rd)',
#       'Malaga WA 6090',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4beced27bac3c9b66db0fde9',
#     'name': 'Subway',
#     'location': {'address': 'Belmont Commercial Centre',
#      'crossStreet': 'cnr Fullham St. & Belmont Ave.',
#      'lat': -31.966894168572566,
#      'lng': 115.93477600436646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.966894168572566,
#        'lng': 115.93477600436646}],
#      'distance': 7192,
#      'postalCode': '6105',
#      'cc': 'AU',
#      'city': 'Cloverdale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Belmont Commercial Centre (cnr Fullham St. & Belmont Ave.)',
#       'Cloverdale WA 6105',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b68f694f964a52016952be3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 1 & 2, Claremont Chambers',
#      'crossStreet': '319 Stirling Hwy',
#      'lat': -31.983191483000713,
#      'lng': 115.78058338081817,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.983191483000713,
#        'lng': 115.78058338081817}],
#      'distance': 8272,
#      'postalCode': '6010',
#      'cc': 'AU',
#      'city': 'Claremont',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 1 & 2, Claremont Chambers (319 Stirling Hwy)',
#       'Claremont WA 6010',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4ba08098f964a5201d7037e3',
#     'name': 'Subway',
#     'location': {'address': '222 Walter Rd West',
#      'crossStreet': 'at Russell St.',
#      'lat': -31.89646252834257,
#      'lng': 115.89428993513229,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.89646252834257,
#        'lng': 115.89428993513229}],
#      'distance': 7029,
#      'postalCode': '6062',
#      'cc': 'AU',
#      'city': 'Morley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['222 Walter Rd West (at Russell St.)',
#       'Morley WA 6062',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b826e05f964a5209ad230e3',
#     'name': 'Subway',
#     'location': {'address': '19 Waterford Ave.',
#      'crossStreet': 'Cnr Kent St. & Manning Rd.',
#      'lat': -32.01100272745731,
#      'lng': 115.88591871004473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01100272745731,
#        'lng': 115.88591871004473}],
#      'distance': 6919,
#      'postalCode': '6152',
#      'cc': 'AU',
#      'city': 'Waterford',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['19 Waterford Ave. (Cnr Kent St. & Manning Rd.)',
#       'Waterford WA 6152',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c62600186b6be9ab6f78b34',
#     'name': 'Subway',
#     'location': {'address': '1128 Albany Hwy',
#      'crossStreet': 'at Bedford St.',
#      'lat': -32.00072064666328,
#      'lng': 115.91875462333354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.00072064666328,
#        'lng': 115.91875462333354}],
#      'distance': 7670,
#      'postalCode': '6102',
#      'cc': 'AU',
#      'city': 'Bentley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1128 Albany Hwy (at Bedford St.)',
#       'Bentley WA 6102',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4cbfb636985aa35d86db4812',
#     'name': 'Subway',
#     'location': {'address': 'Kiosk 5, Food Crt, Westfield Innaloo S/C',
#      'crossStreet': 'Ellen Stirling Blvd',
#      'lat': -31.901306171152413,
#      'lng': 115.79905807971954,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.901306171152413,
#        'lng': 115.79905807971954}],
#      'distance': 8149,
#      'postalCode': '6018',
#      'cc': 'AU',
#      'city': 'Innaloo',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Kiosk 5, Food Crt, Westfield Innaloo S/C (Ellen Stirling Blvd)',
#       'Innaloo WA 6018',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b75438cf964a52066032ee3',
#     'name': 'Subway',
#     'location': {'address': '371 Scarborough Beach Rd',
#      'lat': -31.90223469326936,
#      'lng': 115.7961704196207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.90223469326936,
#        'lng': 115.7961704196207}],
#      'distance': 8275,
#      'postalCode': '6018',
#      'cc': 'AU',
#      'city': 'Innaloo',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['371 Scarborough Beach Rd',
#       'Innaloo WA 6018',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4bb17b0bf964a5200c963ce3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 16A, Hometown Cannington',
#      'crossStreet': '1490 Albany Hwy',
#      'lat': -32.02700710518411,
#      'lng': 115.94699763446765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.02700710518411,
#        'lng': 115.94699763446765}],
#      'distance': 11624,
#      'postalCode': '6107',
#      'cc': 'AU',
#      'city': 'Cannington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 16A, Hometown Cannington (1490 Albany Hwy)',
#       'Cannington WA 6107',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c96e53c72dd224b3569b091',
#     'name': 'Subway',
#     'location': {'lat': -31.90372790379895,
#      'lng': 115.95363100337158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.90372790379895,
#        'lng': 115.95363100337158}],
#      'distance': 10353,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4bdcf7109e2e2d7f8b8de49e',
#     'name': 'Subway',
#     'location': {'address': 'Shop K2, Garden City S/C',
#      'crossStreet': '125 Riseley St.',
#      'lat': -32.0456434396555,
#      'lng': 115.81749722022055,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.0456434396555,
#        'lng': 115.81749722022055}],
#      'distance': 11112,
#      'postalCode': '6154',
#      'cc': 'AU',
#      'city': 'Booragoon',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop K2, Garden City S/C (125 Riseley St.)',
#       'Booragoon WA 6154',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c788e372d3ba14327978bd0',
#     'name': 'Subway',
#     'location': {'address': 'Shop 69, Riverton Forum',
#      'crossStreet': 'cnr High Rd & Willeri Dr.',
#      'lat': -32.03930536129675,
#      'lng': 115.90463947644771,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.03930536129675,
#        'lng': 115.90463947644771}],
#      'distance': 10502,
#      'postalCode': '6148',
#      'cc': 'AU',
#      'city': 'Riverton',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 69, Riverton Forum (cnr High Rd & Willeri Dr.)',
#       'Riverton WA 6148',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b42e1b6f964a520abda25e3',
#     'name': 'Carillon Food Court',
#     'location': {'address': 'Carillon City Mall',
#      'lat': -31.95393902848522,
#      'lng': 115.85851892326777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95393902848522,
#        'lng': 115.85851892326777}],
#      'distance': 230,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Carillon City Mall', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4b88b0eff964a520f60832e3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 2, Southlands S/C',
#      'crossStreet': '39 Burrendah Blvd',
#      'lat': -32.056386607951985,
#      'lng': 115.88073015711196,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.056386607951985,
#        'lng': 115.88073015711196}],
#      'distance': 11698,
#      'postalCode': '6155',
#      'cc': 'AU',
#      'city': 'Willetton',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 2, Southlands S/C (39 Burrendah Blvd)',
#       'Willetton WA 6155',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4ca8513e44a8224b197b1640',
#     'name': 'Subway',
#     'location': {'address': 'Unit 6, 126 Bannister Rd',
#      'crossStreet': 'at Vinnicombe Dr.',
#      'lat': -32.05802025227301,
#      'lng': 115.91692301352346,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05802025227301,
#        'lng': 115.91692301352346}],
#      'distance': 12876,
#      'postalCode': '6155',
#      'cc': 'AU',
#      'city': 'Canning Vale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Unit 6, 126 Bannister Rd (at Vinnicombe Dr.)',
#       'Canning Vale WA 6155',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c1b3198eac020a1287844c2',
#     'name': 'Subway',
#     'location': {'address': 'Shop 81, Centro Maddington S/C',
#      'crossStreet': 'cnr Burslem Dr. & Attfield St.',
#      'lat': -32.053426179999995,
#      'lng': 115.979019,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.053426179999995,
#        'lng': 115.979019}],
#      'distance': 15840,
#      'postalCode': '6109',
#      'cc': 'AU',
#      'city': 'Maddington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 81, Centro Maddington S/C (cnr Burslem Dr. & Attfield St.)',
#       'Maddington WA 6109',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False},
#    {'id': '4c1856b06a21c9b65bf7c897',
#     'name': 'Subway',
#     'location': {'address': '133 Canning Hwy',
#      'lat': -31.982181996376433,
#      'lng': 115.87595257954709,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.982181996376433,
#        'lng': 115.87595257954709}],
#      'distance': 3591,
#      'postalCode': '6151',
#      'cc': 'AU',
#      'city': 'South Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['133 Canning Hwy',
#       'South Perth WA 6151',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551672774',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues1 = results1['response']['venues']

# tranform venues into a dataframe
dataframe1 = json_normalize(venues1)
dataframe1.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
# 4  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...    False
#
#                          id          location.address location.cc  \
# 0  4ba45b50f964a5203e9838e3              73 James St.          AU
# 1  4d6b10cb8fe6a143c81bf0a3   Shop 109, Carillon City          AU
# 2  4b416aecf964a52074c625e3               564 Hay St.          AU
# 3  4bc3ebad920eb7137d341e2c          256 Adelaide Tce          AU
# 4  4c86f818d8086dcba2d59e52  Shop 3, Allendale Square          AU
#
#   location.city location.country location.crossStreet  location.distance  \
# 0   Northbridge        Australia                  NaN                451
# 1         Perth        Australia       207 Murray St.                218
# 2         Perth        Australia                  NaN                275
# 3         Perth        Australia                  NaN                768
# 4         Perth        Australia    77 St Georges Tce                406
#
#                            location.formattedAddress  \
# 0     [73 James St., Northbridge WA 6003, Australia]
# 1  [Shop 109, Carillon City (207 Murray St.), Per...
# 2            [564 Hay St., Perth WA 6000, Australia]
# 3       [256 Adelaide Tce, Perth WA 6000, Australia]
# 4  [Shop 3, Allendale Square (77 St Georges Tce),...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -31.9488897462076...    -31.948890
# 1  [{'label': 'display', 'lat': -31.9538040098629...    -31.953804
# 2  [{'label': 'display', 'lat': -31.9550486769291...    -31.955049
# 3  [{'label': 'display', 'lat': -31.9579173136522...    -31.957917
# 4  [{'label': 'display', 'lat': -31.9557062951224...    -31.955706
#
#    location.lng location.postalCode location.state    name    referralId
# 0    115.858869                6003             WA  Subway  v-1551672774
# 1    115.858556                6000             WA  Subway  v-1551672774
# 2    115.861436                6000             WA  Subway  v-1551672774
# 3    115.865826                6000             WA  Subway  v-1551672774
# 4    115.858019                6000             WA  Subway  v-1551672774

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns1 = ['name', 'categories'] + [col for col in dataframe1.columns if col.startswith('location.')] + ['id']
dataframe_filtered1 = dataframe1.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
dataframe_filtered1['categories'] = dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered1.columns = [column.split('.')[-1] for column in dataframe_filtered1.columns]

dataframe_filtered1
dataframe_filtered1.to_csv('subway.csv')

# %%
venues_map1 = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Perth
#folium.features.CircleMarker([latitude, longitude]).add_to(venues_map1)

# %%
# add the Mexican restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered1.lat, dataframe_filtered1.lng, dataframe_filtered1.categories):
    folium.features.CircleMarker([lat, lng],
                                 radius=5,  color='red', popup=label, 
                                 fill = True, fill_color='blue', fill_opacity=0.6).add_to(venues_map1)
venues_map1
# display map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
