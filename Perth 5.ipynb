# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: - Killed
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H' # your Foursquare ID
CLIENT_SECRET = '3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H
# CLIENT_SECRET:3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ

# %%
address = 'Perth, WA, Australia'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -31.9527121 115.8604796

# %% [markdown]
# # KFC

# %%
search_query = 'KFC'
radius = 200000
print(search_query + ' .... OK!')
# Out:
# KFC .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H&client_secret=3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ&ll=-31.9527121,115.8604796&v=20180604&query=KFC&radius=200000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7ca709351e3d13a92a92a7'},
#  'response': {'venues': [{'id': '4b7ce32ff964a52064a82fe3',
#     'name': 'KFC',
#     'location': {'address': '92 William Street',
#      'crossStreet': 'btwn Murray St and Hay St',
#      'lat': -31.952856651203987,
#      'lng': 115.85734271316738,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.952856651203987,
#        'lng': 115.85734271316738}],
#      'distance': 296,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['92 William Street (btwn Murray St and Hay St)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bfa25e88d30d13a4d430318',
#     'name': 'KFC',
#     'location': {'address': 'Wellington St',
#      'crossStreet': 'btwn Barrack St and William St',
#      'lat': -31.952171549135247,
#      'lng': 115.85937657176754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.952171549135247,
#        'lng': 115.85937657176754}],
#      'distance': 120,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Wellington St (btwn Barrack St and William St)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4d70e524766da143202a55ad',
#     'name': 'KFC',
#     'location': {'address': '515 Hay St.',
#      'crossStreet': 'at Denis St.',
#      'lat': -31.94721903348061,
#      'lng': 115.82269016587034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94721903348061,
#        'lng': 115.82269016587034}],
#      'distance': 3621,
#      'postalCode': '6008',
#      'cc': 'AU',
#      'city': 'Subiaco',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['515 Hay St. (at Denis St.)',
#       'Subiaco WA 6008',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bd03512462cb713bae3d707',
#     'name': 'KFC',
#     'location': {'address': 'Abernathy Rd',
#      'crossStreet': 'Fulham St',
#      'lat': -31.964233885781947,
#      'lng': 115.93770190661172,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.964233885781947,
#        'lng': 115.93770190661172}],
#      'distance': 7405,
#      'cc': 'AU',
#      'city': 'Belmont',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Abernathy Rd (Fulham St)',
#       'Belmont WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bc82bff0050b7130befb93b',
#     'name': 'KFC',
#     'location': {'address': 'Garden City Food Court',
#      'lat': -32.0330559742737,
#      'lng': 115.8352169906696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.0330559742737,
#        'lng': 115.8352169906696}],
#      'distance': 9256,
#      'postalCode': '6154',
#      'cc': 'AU',
#      'city': 'Booragoon',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Garden City Food Court',
#       'Booragoon WA 6154',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bf3be0e706e20a1077ea898',
#     'name': 'KFC',
#     'location': {'address': '200 Karrinyup Rd',
#      'lat': -31.877609843750708,
#      'lng': 115.77706124331827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.877609843750708,
#        'lng': 115.77706124331827}],
#      'distance': 11490,
#      'postalCode': '6018',
#      'cc': 'AU',
#      'city': 'Karrinyup',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['200 Karrinyup Rd',
#       'Karrinyup WA 6018',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4b88e411f964a5203c1232e3',
#     'name': 'KFC',
#     'location': {'address': '49 Yirrigan Dr',
#      'crossStreet': 'Farrier Rd',
#      'lat': -31.872918277198494,
#      'lng': 115.8605754780456,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.872918277198494,
#        'lng': 115.8605754780456}],
#      'distance': 8882,
#      'postalCode': '6061',
#      'cc': 'AU',
#      'city': 'Mirrabooka',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['49 Yirrigan Dr (Farrier Rd)',
#       'Mirrabooka WA 6061',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4b836084f964a520680431e3',
#     'name': 'KFC',
#     'location': {'address': '70 Marangaroo Dr',
#      'crossStreet': 'Templeton Cres',
#      'lat': -31.834393354030087,
#      'lng': 115.83013284387572,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.834393354030087,
#        'lng': 115.83013284387572}],
#      'distance': 13479,
#      'postalCode': '6064',
#      'cc': 'AU',
#      'city': 'Girrawheen',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['70 Marangaroo Dr (Templeton Cres)',
#       'Girrawheen WA 6064',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4cc27a001e596dcb5c9cc367',
#     'name': 'KFC',
#     'location': {'address': 'Spencer Rd',
#      'crossStreet': 'at Southdown Pl',
#      'lat': -32.04554803360911,
#      'lng': 115.95204054344887,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.04554803360911,
#        'lng': 115.95204054344887}],
#      'distance': 13472,
#      'postalCode': '6108',
#      'cc': 'AU',
#      'city': 'Thornlie',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Spencer Rd (at Southdown Pl)',
#       'Thornlie WA 6108',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bcedbd8fb84c9b6655f243e',
#     'name': 'KFC',
#     'location': {'address': '228 Great Eastern Hwy',
#      'crossStreet': 'at Lloyd St',
#      'lat': -31.891573154130803,
#      'lng': 116.01386529951567,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.891573154130803,
#        'lng': 116.01386529951567}],
#      'distance': 16010,
#      'postalCode': '6056',
#      'cc': 'AU',
#      'city': 'Midland',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['228 Great Eastern Hwy (at Lloyd St)',
#       'Midland WA 6056',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4d665a7105a7f04d4d8bb18f',
#     'name': 'KFC',
#     'location': {'address': '13 Canning Hwy',
#      'crossStreet': 'Mill Point Rd',
#      'lat': -31.974976185773695,
#      'lng': 115.88195827835713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.974976185773695,
#        'lng': 115.88195827835713}],
#      'distance': 3202,
#      'postalCode': '6151',
#      'cc': 'AU',
#      'city': 'South Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['13 Canning Hwy (Mill Point Rd)',
#       'South Perth WA 6151',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bb6e3fc46d4a593a3f0c6c0',
#     'name': 'KFC',
#     'location': {'address': 'Whitfords Ave',
#      'crossStreet': 'nr Endeavour Rd',
#      'lat': -31.796686683636786,
#      'lng': 115.74650863318232,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.796686683636786,
#        'lng': 115.74650863318232}],
#      'distance': 20438,
#      'postalCode': '6026',
#      'cc': 'AU',
#      'city': 'Hillarys',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Whitfords Ave (nr Endeavour Rd)',
#       'Hillarys WA 6026',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4ee87e2702d5895bd74ee090',
#     'name': 'KFC',
#     'location': {'address': '11 Deloraine Way',
#      'crossStreet': 'Henley Brook Ave',
#      'lat': -31.796546586528574,
#      'lng': 115.97843600641717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.796546586528574,
#        'lng': 115.97843600641717}],
#      'distance': 20653,
#      'postalCode': '6055',
#      'cc': 'AU',
#      'city': 'Henley Brook',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['11 Deloraine Way (Henley Brook Ave)',
#       'Henley Brook WA 6055',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4b9c8115f964a520096d36e3',
#     'name': 'KFC',
#     'location': {'address': '2 Wiluna St',
#      'crossStreet': 'Charles St',
#      'lat': -31.911911095077127,
#      'lng': 115.84706127107323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.911911095077127,
#        'lng': 115.84706127107323}],
#      'distance': 4715,
#      'postalCode': '6050',
#      'cc': 'AU',
#      'city': 'Yokine',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['2 Wiluna St (Charles St)',
#       'Yokine WA 6050',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bb97886b35776b0d3f8c901',
#     'name': 'KFC',
#     'location': {'address': '420 Joondalup Dr',
#      'crossStreet': 'nr Cord St',
#      'lat': -31.742228390150498,
#      'lng': 115.7639269807606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.742228390150498,
#        'lng': 115.7639269807606}],
#      'distance': 25146,
#      'postalCode': '6027',
#      'cc': 'AU',
#      'city': 'Joondalup',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['420 Joondalup Dr (nr Cord St)',
#       'Joondalup WA 6027',
#       'Australia']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4b697560f964a5202ba32be3',
#     'name': 'KFC',
#     'location': {'address': '230 Manning Rd',
#      'crossStreet': 'Kent St',
#      'lat': -32.012179430943824,
#      'lng': 115.8863375842028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.012179430943824,
#        'lng': 115.8863375842028}],
#      'distance': 7055,
#      'postalCode': '6152',
#      'cc': 'AU',
#      'city': 'Karawara',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['230 Manning Rd (Kent St)',
#       'Karawara WA 6152',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4ba31862f964a520952b38e3',
#     'name': 'KFC',
#     'location': {'address': '194 Great Eastern Hwy.',
#      'crossStreet': 'at Grandstand Rd.',
#      'lat': -31.941722520322482,
#      'lng': 115.92505453999476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.941722520322482,
#        'lng': 115.92505453999476}],
#      'distance': 6221,
#      'postalCode': '6104',
#      'cc': 'AU',
#      'city': 'Belmont',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['194 Great Eastern Hwy. (at Grandstand Rd.)',
#       'Belmont WA 6104',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bc1a8f24cdfc9b6cdef9421',
#     'name': 'KFC',
#     'location': {'address': '4 North Lake Rd.',
#      'lat': -32.031241240567276,
#      'lng': 115.81592247274364,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.031241240567276,
#        'lng': 115.81592247274364}],
#      'distance': 9701,
#      'postalCode': '6154',
#      'cc': 'AU',
#      'city': 'Alfred Cove',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['4 North Lake Rd.',
#       'Alfred Cove WA 6154',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '4bb33b9514cfd13a5abf15ab',
#     'name': 'KFC',
#     'location': {'address': 'Marmion Ave',
#      'crossStreet': 'Ocean Keys Bvd',
#      'lat': -31.68994401119068,
#      'lng': 115.71540338112142,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.68994401119068,
#        'lng': 115.71540338112142}],
#      'distance': 32309,
#      'postalCode': '6030',
#      'cc': 'AU',
#      'city': 'Clarkson',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Marmion Ave (Ocean Keys Bvd)',
#       'Clarkson WA 6030',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False},
#    {'id': '5bbdcbf2a35dce002c236cb3',
#     'name': 'KFC',
#     'location': {'address': 'Bulter Boulevard',
#      'lat': -31.638333,
#      'lng': 115.695338,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.638333,
#        'lng': 115.695338}],
#      'distance': 38325,
#      'postalCode': '6036',
#      'cc': 'AU',
#      'city': 'Butler',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Bulter Boulevard', 'Butler WA 6036', 'Australia']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673097',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 2  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 4  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
#
#                          id        location.address location.cc location.city  \
# 0  4b7ce32ff964a52064a82fe3       92 William Street          AU         Perth
# 1  4bfa25e88d30d13a4d430318           Wellington St          AU         Perth
# 2  4d70e524766da143202a55ad             515 Hay St.          AU       Subiaco
# 3  4bd03512462cb713bae3d707            Abernathy Rd          AU       Belmont
# 4  4bc82bff0050b7130befb93b  Garden City Food Court          AU     Booragoon
#
#   location.country            location.crossStreet  location.distance  \
# 0        Australia       btwn Murray St and Hay St                296
# 1        Australia  btwn Barrack St and William St                120
# 2        Australia                    at Denis St.               3621
# 3        Australia                       Fulham St               7405
# 4        Australia                             NaN               9256
#
#                            location.formattedAddress  \
# 0  [92 William Street (btwn Murray St and Hay St)...
# 1  [Wellington St (btwn Barrack St and William St...
# 2  [515 Hay St. (at Denis St.), Subiaco WA 6008, ...
# 3  [Abernathy Rd (Fulham St), Belmont WA, Australia]
# 4  [Garden City Food Court, Booragoon WA 6154, Au...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -31.9528566512039...    -31.952857
# 1  [{'label': 'display', 'lat': -31.9521715491352...    -31.952172
# 2  [{'label': 'display', 'lat': -31.9472190334806...    -31.947219
# 3  [{'label': 'display', 'lat': -31.9642338857819...    -31.964234
# 4  [{'label': 'display', 'lat': -32.0330559742737...    -32.033056
#
#    location.lng location.postalCode location.state name    referralId
# 0    115.857343                6000             WA  KFC  v-1551673097
# 1    115.859377                6000             WA  KFC  v-1551673097
# 2    115.822690                6008             WA  KFC  v-1551673097
# 3    115.937702                 NaN             WA  KFC  v-1551673097
# 4    115.835217                6154             WA  KFC  v-1551673097

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
dataframe_filtered.to_csv('KFC.csv')

# %%
dataframe_filtered.name
# Out:
# 0     KFC
# 1     KFC
# 2     KFC
# 3     KFC
# 4     KFC
# 5     KFC
# 6     KFC
# 7     KFC
# 8     KFC
# 9     KFC
# 10    KFC
# 11    KFC
# 12    KFC
# 13    KFC
# 14    KFC
# 15    KFC
# 16    KFC
# 17    KFC
# 18    KFC
# 19    KFC
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Perth

# add a red circle marker to represent the Paris
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Perth',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Mexican restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Foodcourt

# %%
search_query = 'Foodcourt'
radius = 200000
print(search_query + ' .... OK!')
# Out:
# Foodcourt .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DWLSXTZ222PPSQULJSH0K0AZGIEFKEAFVRQVX2LQI0TNNK0H&client_secret=3VJRDWE0FWLWJIB24Q4A5D0L5OBEKK022BHQVFKSGXQZ5HUZ&ll=-31.9527121,115.8604796&v=20180604&query=Foodcourt&radius=200000&limit=100'

# %%
results1 = requests.get(url).json()
results1
# Out:
# {'meta': {'code': 200, 'requestId': '5c7ca7561ed2196e437bcf3a'},
#  'response': {'venues': [{'id': '4b42e1b6f964a520abda25e3',
#     'name': 'Carillon Food Court',
#     'location': {'address': 'Carillon City Mall',
#      'lat': -31.95393902848522,
#      'lng': 115.85851892326777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95393902848522,
#        'lng': 115.85851892326777}],
#      'distance': 230,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Carillon City Mall', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4b4d5dbff964a52078d126e3',
#     'name': 'ENEX Food Court',
#     'location': {'address': '100 St. Georges Terrace',
#      'crossStreet': 'William St.',
#      'lat': -31.954112038530372,
#      'lng': 115.85802525028325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.954112038530372,
#        'lng': 115.85802525028325}],
#      'distance': 279,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['100 St. Georges Terrace (William St.)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '445835338'},
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '505565fee4b0e5434d16860d',
#     'name': 'Raine Square Food Court',
#     'location': {'lat': -31.95138918378649,
#      'lng': 115.85745677288004,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95138918378649,
#        'lng': 115.85745677288004}],
#      'distance': 321,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4b5686d8f964a5200b1428e3',
#     'name': '160 Central Foodcourt',
#     'location': {'address': '811 Hay St, Perth',
#      'lat': -31.953176,
#      'lng': 115.855513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953176,
#        'lng': 115.855513}],
#      'distance': 471,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['811 Hay St, Perth', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c6cb92a99b9236a2888e3c9',
#     'name': 'One40william Food Court',
#     'location': {'address': '140 William St.',
#      'lat': -31.952667971977633,
#      'lng': 115.85797471077905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.952667971977633,
#        'lng': 115.85797471077905}],
#      'distance': 236,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['140 William St.', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4e57163cb993bf36edfd7a50',
#     'name': 'The Food Court at Crown',
#     'location': {'address': 'Bolton Ave.',
#      'crossStreet': 'in Crown Perth',
#      'lat': -31.962013938640705,
#      'lng': 115.89412213857024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.962013938640705,
#        'lng': 115.89412213857024}],
#      'distance': 3341,
#      'postalCode': '6100',
#      'cc': 'AU',
#      'city': 'Burswood',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Bolton Ave. (in Crown Perth)',
#       'Burswood WA 6100',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4b5bc9e5f964a5204e1629e3',
#     'name': 'David Jones Food Court',
#     'location': {'address': 'Murray St',
#      'lat': -31.953832590801785,
#      'lng': 115.85995462939972,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953832590801785,
#        'lng': 115.85995462939972}],
#      'distance': 134,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Murray St', 'Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4e2cf292b61cd01083858072',
#     'name': 'Westcentre Arcade Foodcourt',
#     'location': {'address': 'Hay St West Perth',
#      'crossStreet': 'Outram St',
#      'lat': -31.948241694203475,
#      'lng': 115.84075915615337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.948241694203475,
#        'lng': 115.84075915615337}],
#      'distance': 1928,
#      'cc': 'AU',
#      'city': 'West Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Hay St West Perth (Outram St)',
#       'West Perth WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4d104907b765224ba0f4e932',
#     'name': 'Food Court',
#     'location': {'address': 'Ellen Stirling Blvd',
#      'crossStreet': 'nr Scarborough Beach Road',
#      'lat': -31.90143299182428,
#      'lng': 115.79930819671829,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.90143299182428,
#        'lng': 115.79930819671829}],
#      'distance': 8123,
#      'postalCode': '6018',
#      'cc': 'AU',
#      'city': 'Innaloo',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Ellen Stirling Blvd (nr Scarborough Beach Road)',
#       'Innaloo WA 6018',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4d6b10cb8fe6a143c81bf0a3',
#     'name': 'Subway',
#     'location': {'address': 'Shop 109, Carillon City',
#      'crossStreet': '207 Murray St.',
#      'lat': -31.95380400986294,
#      'lng': 115.85855634680627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95380400986294,
#        'lng': 115.85855634680627}],
#      'distance': 218,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 109, Carillon City (207 Murray St.)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4d11bcdb90d0a1434adf9f09',
#     'name': 'Carousel Food Court',
#     'location': {'lat': -32.01775824064855,
#      'lng': 115.93733108405262,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01775824064855,
#        'lng': 115.93733108405262}],
#      'distance': 10251,
#      'cc': 'AU',
#      'city': 'Cannington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Cannington WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4e2659b01f6eb1ae13953db7',
#     'name': 'Food Court',
#     'location': {'address': 'West Perth',
#      'lat': -31.94801699044562,
#      'lng': 115.84080808062356,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.94801699044562,
#        'lng': 115.84080808062356}],
#      'distance': 1930,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['West Perth', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '5a336c5895da0c19c7d285a8',
#     'name': 'The Underground Food Court',
#     'location': {'lat': -31.955688,
#      'lng': 115.858168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.955688,
#        'lng': 115.858168}],
#      'distance': 396,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Perth WA 6000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '5018c212e4b00b74aacee37f',
#     'name': 'Cafe Court',
#     'location': {'address': 'Brookfield Place, 125 St Georges Terrace',
#      'crossStreet': 'btwn William St and King St',
#      'lat': -31.95531939322089,
#      'lng': 115.8545507924115,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95531939322089,
#        'lng': 115.8545507924115}],
#      'distance': 630,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Brookfield Place, 125 St Georges Terrace (btwn William St and King St)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4b4d59eef964a52039d126e3',
#     'name': 'Allendale Food Court',
#     'location': {'address': '77 St Georges Terrace',
#      'crossStreet': 'Sherwood Court',
#      'lat': -31.95564100455713,
#      'lng': 115.85825708232969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.95564100455713,
#        'lng': 115.85825708232969}],
#      'distance': 387,
#      'postalCode': '6000',
#      'cc': 'AU',
#      'city': 'Perth',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['77 St Georges Terrace (Sherwood Court)',
#       'Perth WA 6000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '584791d70a3d5404eddadeed',
#     'name': 'Brookfield Place food court',
#     'location': {'lat': -31.955013,
#      'lng': 115.854315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.955013,
#        'lng': 115.854315}],
#      'distance': 636,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4ce4fb6be1dba35d0c0d7f88',
#     'name': 'The Verandah Food Court',
#     'location': {'address': 'Collier Rd',
#      'crossStreet': 'nr Dewar St',
#      'lat': -31.89718543499798,
#      'lng': 115.8993352562402,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.89718543499798,
#        'lng': 115.8993352562402}],
#      'distance': 7189,
#      'cc': 'AU',
#      'city': 'Morley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Collier Rd (nr Dewar St)',
#       'Morley WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4b60277ef964a520acd729e3',
#     'name': 'Cambridge Forum International Food Court',
#     'location': {'address': '350 Cambridge St',
#      'crossStreet': 'btw Alexander & Simper',
#      'lat': -31.9402551895078,
#      'lng': 115.80989802611094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.9402551895078,
#        'lng': 115.80989802611094}],
#      'distance': 4975,
#      'postalCode': '6014',
#      'cc': 'AU',
#      'city': 'Wembley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['350 Cambridge St (btw Alexander & Simper)',
#       'Wembley WA 6014',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c2d8397e760c9b66a174549',
#     'name': 'Food Court',
#     'location': {'address': 'Midland Gate Shopping Centre',
#      'lat': -31.889371706429984,
#      'lng': 116.01019222989198,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.889371706429984,
#        'lng': 116.01019222989198}],
#      'distance': 15805,
#      'postalCode': '6056',
#      'cc': 'AU',
#      'city': 'Midland',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Midland Gate Shopping Centre',
#       'Midland WA 6056',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '50628960e4b0b7a3c47f5112',
#     'name': 'Mixed Food court (next door to Anz)',
#     'location': {'lat': -31.953286,
#      'lng': 115.852471,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.953286,
#        'lng': 115.852471}],
#      'distance': 759,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '514d991ee4b020b3aa0fb70d',
#     'name': "McDonald's",
#     'location': {'lat': -31.96205522998167,
#      'lng': 115.89422236485144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.96205522998167,
#        'lng': 115.89422236485144}],
#      'distance': 3352,
#      'cc': 'AU',
#      'city': 'Burswood',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Burswood WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4bc29e11920eb713a6841c2c',
#     'name': 'Central Cafe',
#     'location': {'address': 'Building 12',
#      'crossStreet': 'Edith Cowan University (ECU)',
#      'lat': -31.919540927971262,
#      'lng': 115.86695396045724,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.919540927971262,
#        'lng': 115.86695396045724}],
#      'distance': 3742,
#      'postalCode': '6050',
#      'cc': 'AU',
#      'city': 'Mt Lawley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Building 12 (Edith Cowan University (ECU))',
#       'Mt Lawley WA 6050',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1a1941735',
#       'name': 'College Cafeteria',
#       'pluralName': 'College Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '5c2ee36bf00a70002c4adcd5',
#     'name': 'Food Court',
#     'location': {'address': 'Dunreath Drive',
#      'lat': -31.93723,
#      'lng': 115.948582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.93723,
#        'lng': 115.948582}],
#      'distance': 8498,
#      'postalCode': '6105',
#      'cc': 'AU',
#      'city': 'Perth Airport',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Dunreath Drive',
#       'Perth Airport WA 6105',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4de767667d8b1f2dd2966c39',
#     'name': 'Kingsway Foodcourt',
#     'location': {'address': '168 Wanneroo Rd',
#      'lat': -31.81834909493925,
#      'lng': 115.82387355004978,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.81834909493925,
#        'lng': 115.82387355004978}],
#      'distance': 15352,
#      'postalCode': '6065',
#      'cc': 'AU',
#      'city': 'Madeley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['168 Wanneroo Rd', 'Madeley WA 6065', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4d898efe7139b1f7be21b8d4',
#     'name': 'IKEA Restaurant',
#     'location': {'address': '5 Sunray Dr',
#      'crossStreet': 'at Baumea Way',
#      'lat': -31.896443644329874,
#      'lng': 115.80326496900543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.896443644329874,
#        'lng': 115.80326496900543}],
#      'distance': 8273,
#      'postalCode': '6018',
#      'cc': 'AU',
#      'city': 'Innaloo',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['5 Sunray Dr (at Baumea Way)',
#       'Innaloo WA 6018',
#       'Australia']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4d997a490caaa143adb4c5b3',
#     'name': 'Cockburn Gateway Food Court',
#     'location': {'address': 'Cockburn Gateway Shopping Centre',
#      'lat': -32.131594077991444,
#      'lng': 115.85719442729511,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.131594077991444,
#        'lng': 115.85719442729511}],
#      'distance': 19915,
#      'cc': 'AU',
#      'city': 'Success',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Cockburn Gateway Shopping Centre',
#       'Success WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4b133195f964a520579523e3',
#     'name': "McDonald's",
#     'location': {'address': '1342 Albany Hwy',
#      'crossStreet': 'at Cecil Ave',
#      'lat': -32.01809558938474,
#      'lng': 115.93533250478593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.01809558938474,
#        'lng': 115.93533250478593}],
#      'distance': 10145,
#      'cc': 'AU',
#      'city': 'Cannington',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1342 Albany Hwy (at Cecil Ave)',
#       'Cannington WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4b763997f964a52016442ee3',
#     'name': 'Belmont Forum Food Court',
#     'location': {'address': '227 Belmont Ave',
#      'crossStreet': 'Fulham St',
#      'lat': -31.9642846167255,
#      'lng': 115.93638059870344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.9642846167255,
#        'lng': 115.93638059870344}],
#      'distance': 7283,
#      'cc': 'AU',
#      'city': 'Cloverdale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['227 Belmont Ave (Fulham St)',
#       'Cloverdale WA',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c622c6479d1e21e20b0d515',
#     'name': 'Indian Cuisine @ Cambridge Food Court',
#     'location': {'address': '350 Cambridge st',
#      'lat': -31.940551614940937,
#      'lng': 115.80866808848745,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.940551614940937,
#        'lng': 115.80866808848745}],
#      'distance': 5077,
#      'postalCode': '6014',
#      'cc': 'AU',
#      'city': 'Wembley',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['350 Cambridge st', 'Wembley WA 6014', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4b62cc48f964a52020532ae3',
#     'name': 'International Food Court',
#     'location': {'lat': -31.99285474931147,
#      'lng': 115.91157317792991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.99285474931147,
#        'lng': 115.91157317792991}],
#      'distance': 6576,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c6a16dc35d3be9a832a2106',
#     'name': 'Garden City Food Court',
#     'location': {'address': '125 Riseley St',
#      'lat': -32.03307565775423,
#      'lng': 115.83520899984318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.03307565775423,
#        'lng': 115.83520899984318}],
#      'distance': 9258,
#      'postalCode': '6154',
#      'cc': 'AU',
#      'city': 'Booragoon',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['125 Riseley St', 'Booragoon WA 6154', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c8c677e5e048cfa88f7cccd',
#     'name': 'Food Court @ E Shed Markets',
#     'location': {'address': 'Victoria Quay Road',
#      'lat': -32.052930886853126,
#      'lng': 115.74275249596946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.052930886853126,
#        'lng': 115.74275249596946}],
#      'distance': 15747,
#      'postalCode': '6160',
#      'cc': 'AU',
#      'city': 'Fremantle',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Victoria Quay Road',
#       'Fremantle WA 6160',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4cd8fcd05e1b721eebf33cd9',
#     'name': 'Karrinyup Food Court',
#     'location': {'address': '200 Karrinyup Road',
#      'lat': -31.875922633970013,
#      'lng': 115.77958245762242,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -31.875922633970013,
#        'lng': 115.77958245762242}],
#      'distance': 11467,
#      'cc': 'AU',
#      'city': 'Karrinyup',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['200 Karrinyup Road', 'Karrinyup WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c1c9d1763750f4722d2b667',
#     'name': 'Southlands Food Court',
#     'location': {'lat': -32.05657159068166,
#      'lng': 115.87995466391027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.05657159068166,
#        'lng': 115.87995466391027}],
#      'distance': 11706,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c3e8ee5db3b1b8d24ad6595',
#     'name': 'Southlands Boulevard Food Court',
#     'location': {'address': 'Burrendah Blvd',
#      'crossStreet': 'Pine Tree Gully Rd',
#      'lat': -32.06046532401831,
#      'lng': 115.88819836672863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.06046532401831,
#        'lng': 115.88819836672863}],
#      'distance': 12277,
#      'postalCode': '6155',
#      'cc': 'AU',
#      'city': 'Willetton',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Burrendah Blvd (Pine Tree Gully Rd)',
#       'Willetton WA 6155',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '593e6410e7a237489ebbf466',
#     'name': 'Canningvale Food Court',
#     'location': {'lat': -32.068646,
#      'lng': 115.894914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.068646,
#        'lng': 115.894914}],
#      'distance': 13308,
#      'postalCode': '6155',
#      'cc': 'AU',
#      'city': 'Canning Vale',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Canning Vale WA 6155', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4fdeaa75e4b0d33169b86c6f',
#     'name': 'Food Court - Rockingham Shopping Centre',
#     'location': {'address': '1 Council Ave',
#      'lat': -32.289619906552566,
#      'lng': 115.74578378527207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.289619906552566,
#        'lng': 115.74578378527207}],
#      'distance': 39031,
#      'postalCode': '6168',
#      'cc': 'AU',
#      'city': 'Rockingham',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['1 Council Ave', 'Rockingham WA 6168', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c36f18aae2da59397f8fdc5',
#     'name': 'Spencer Village Food Court',
#     'location': {'address': '200 Spencer Rd',
#      'crossStreet': 'Southdown Place',
#      'lat': -32.045541815067814,
#      'lng': 115.9527512913074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.045541815067814,
#        'lng': 115.9527512913074}],
#      'distance': 13515,
#      'postalCode': '6108',
#      'cc': 'AU',
#      'city': 'Thornlie',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['200 Spencer Rd (Southdown Place)',
#       'Thornlie WA 6108',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4e5dd9ced22d7239c19aa9e4',
#     'name': 'Pheonix Food Court',
#     'location': {'lat': -32.09776865205569,
#      'lng': 115.7702693412527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.09776865205569,
#        'lng': 115.7702693412527}],
#      'distance': 18254,
#      'cc': 'AU',
#      'city': 'Spearwood',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['Spearwood WA', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4c10bf43f1b6a59346507c27',
#     'name': 'Armadale Food Court',
#     'location': {'lat': -32.150637339648,
#      'lng': 116.01508647049909,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.150637339648,
#        'lng': 116.01508647049909}],
#      'distance': 26424,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '5abf57f61de7657fd716a872',
#     'name': 'Food Court',
#     'location': {'address': '330 Pinjarra Road',
#      'lat': -32.53478,
#      'lng': 115.74261,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.53478,
#        'lng': 115.74261}],
#      'distance': 65738,
#      'postalCode': '6210',
#      'cc': 'AU',
#      'city': 'Mandurah',
#      'state': 'WA',
#      'country': 'Australia',
#      'formattedAddress': ['330 Pinjarra Road',
#       'Mandurah WA 6210',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False},
#    {'id': '4d81d2427252a1cd454da15d',
#     'name': 'Forum Food Court',
#     'location': {'lat': -32.535342,
#      'lng': 115.741647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -32.535342,
#        'lng': 115.741647}],
#      'distance': 65815,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d169941735',
#       'name': 'Australian Restaurant',
#       'pluralName': 'Australian Restaurants',
#       'shortName': 'Australian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1551673174',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues1 = results1['response']['venues']

# tranform venues into a dataframe
dataframe1 = json_normalize(venues1)
dataframe1.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 3  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 4  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
#
#                          id         location.address location.cc  \
# 0  4b42e1b6f964a520abda25e3       Carillon City Mall          AU
# 1  4b4d5dbff964a52078d126e3  100 St. Georges Terrace          AU
# 2  505565fee4b0e5434d16860d                      NaN          AU
# 3  4b5686d8f964a5200b1428e3        811 Hay St, Perth          AU
# 4  4c6cb92a99b9236a2888e3c9          140 William St.          AU
#
#   location.city location.country location.crossStreet  location.distance  \
# 0         Perth        Australia                  NaN                230
# 1         Perth        Australia          William St.                279
# 2           NaN        Australia                  NaN                321
# 3         Perth        Australia                  NaN                471
# 4         Perth        Australia                  NaN                236
#
#                            location.formattedAddress  \
# 0     [Carillon City Mall, Perth WA 6000, Australia]
# 1  [100 St. Georges Terrace (William St.), Perth ...
# 2                                        [Australia]
# 3      [811 Hay St, Perth, Perth WA 6000, Australia]
# 4        [140 William St., Perth WA 6000, Australia]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': -31.9539390284852...    -31.953939
# 1  [{'label': 'display', 'lat': -31.9541120385303...    -31.954112
# 2  [{'label': 'display', 'lat': -31.9513891837864...    -31.951389
# 3  [{'label': 'display', 'lat': -31.953176, 'lng'...    -31.953176
# 4  [{'label': 'display', 'lat': -31.9526679719776...    -31.952668
#
#    location.lng location.postalCode location.state                     name  \
# 0    115.858519                6000             WA      Carillon Food Court
# 1    115.858025                6000             WA          ENEX Food Court
# 2    115.857457                 NaN            NaN  Raine Square Food Court
# 3    115.855513                6000             WA    160 Central Foodcourt
# 4    115.857975                6000             WA  One40william Food Court
#
#      referralId venuePage.id
# 0  v-1551673174          NaN
# 1  v-1551673174    445835338
# 2  v-1551673174          NaN
# 3  v-1551673174          NaN
# 4  v-1551673174          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns1 = ['name', 'categories'] + [col for col in dataframe1.columns if col.startswith('location.')] + ['id']
dataframe_filtered1 = dataframe1.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
dataframe_filtered1['categories'] = dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered1.columns = [column.split('.')[-1] for column in dataframe_filtered1.columns]

dataframe_filtered1

dataframe_filtered1.to_csv('Foodcourt.csv')

# %%
venues_map1 = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Perth
#folium.features.CircleMarker([latitude, longitude]).add_to(venues_map1)

# %%
# add the Mexican restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered1.lat, dataframe_filtered1.lng, dataframe_filtered1.categories):
    folium.features.CircleMarker([lat, lng],
                                 radius=5,  color='red', popup=label, 
                                 fill = True, fill_color='blue', fill_opacity=0.6).add_to(venues_map1)
venues_map1
# display map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
